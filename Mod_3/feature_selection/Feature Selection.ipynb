# %% [markdown]
# # Feature Selection
#
# Feature selection is the process of selecting a subset of relevant features for use in model construction

# %% [markdown]
# ## Top reasons to use feature selection are:
# * It enables the machine learning algorithm to train faster.
# * It reduces the complexity of a model and makes it easier to interpret.
# * It improves the accuracy of a model if the right subset is chosen.
# * It reduces overfitting.

# %% [markdown]
# ***Import the packages we will use for this notebook***

# %%
import pandas as pd
pd.set_option('display.max_columns', 300)
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
import seaborn as sns
sns.set(style="whitegrid")

# %% [markdown]
# ***Set up or initial dataframe by removing variable and transforming others.***

# %%
df_base = pd.read_csv('kc_house_data.csv',index_col='id')
df_base['yr_old']=2017 - df_base['yr_built']

df_base = df_base[['price','bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'waterfront', 'condition', 'grade',
       'sqft_basement', 'yr_old']]

# %% [markdown]
# #### Data Cleaning
#
# This data set is very clean since it came from Kaggle. If it wasn't so clean what are some things I would want to check on for data cleaning?

# %% [markdown]
# -
# -
# -
# -

# %% [markdown]
# ## Outlier Detection: Z-Score Method
#
# The intuition behind the Z-score method of outlier detection is that, once we’ve centred and rescaled the data, anything that is too far from zero (the threshold is usually a Z-score of 3 or -3) should be considered an outlier.

# %% [markdown]
# ***Function to find outliers***

# %%
def outliers_z_score(data, th):
    threshold = th

    mean_y = np.mean(data)
    stdev_y = np.std(data)
    z_scores = [(y - mean_y) / stdev_y for y in data]
    return np.where(np.abs(z_scores) > threshold)

# %% [markdown]
# ### Modified Z-score method
#
# A benefit of the modified Z-score method is that it uses the median and MAD rather than the mean and standard deviation. The median and MAD are robust measures of central tendency and dispersion

# %%
def outliers_modified_z_score(data, th):
    threshold = th

    median_y = np.median(data)
    median_absolute_deviation_y = np.median([np.abs(y - median_y) for y in data])
    modified_z_scores = [0.6745 * (y - median_y) / median_absolute_deviation_y
                         for y in data]
    return np.where(np.abs(modified_z_scores) > threshold)

# %% [markdown]
# ### IQR method
#
# Another robust method for labeling outliers is the IQR (interquartile range) method of outlier detection developed by John Tukey, the pioneer of exploratory data analysis.
#
#  Tukey considered any data point that fell outside of either 1.5 times the IQR below the first – or 1.5 times the IQR above the third – quartile to be “outside” or “far out”.

# %% [markdown]
# <img src='./boxplot.png' width=400/>

# %%
def outliers_iqr(data):
    quartile_1, quartile_3 = np.percentile(data, [25, 75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 1.5)
    upper_bound = quartile_3 + (iqr * 1.5)
    return np.where((data > upper_bound) | (data < lower_bound))

# %% [markdown]
# ***Let's look at the box and whiskers plot for our variables***

# %%
for i in df_base.columns:
    df_base.boxplot(column=i)
    plt.show()

# %% [markdown]
# ***Based on our boxplot, we will remove houses that cost more than $4,000,000***

# %%
df_base = df_base[df_base.price < 4000000]
target = df_base.price
features_base = df_base[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'waterfront', 'condition', 'grade',
       'sqft_basement', 'yr_old']]
df_base.shape
# Out:
# (21601, 11)

# %% [markdown]
# ***Now we will create polynomial and interaction terms***

# %%
poly = PolynomialFeatures(degree=3, include_bias=False)
poly.fit(features_base)
column_names = poly.get_feature_names(features_base.columns)
df_poly= pd.DataFrame(poly.transform(features_base), columns=column_names)

X_train_base, X_test_base, y_train_base, y_test = train_test_split(df_poly, target, random_state=34,test_size=0.2)

# %% [markdown]
# ***Now we will scale those terms***

# %%
scaler = StandardScaler()
scaler.fit(X_train_base)
X_train_base =pd.DataFrame(data=scaler.transform(X_train_base), columns=column_names)
X_test_base =pd.DataFrame(data=scaler.transform(X_test_base), columns=column_names)

# %%
print(X_train_base.shape)
print(X_test_base.shape)
X_train_base.head()
# Out:
# (17280, 285)
# (4321, 285)
#    bedrooms  bathrooms  sqft_living  sqft_lot    floors  waterfront  \
# 0  0.672663   1.818019     1.671271 -0.230213  0.933798   -0.088404
# 1 -0.391966   0.181529    -0.489740 -0.203612 -0.912641   -0.088404
# 2 -0.391966  -0.473067    -0.555893 -0.153920 -0.912641   -0.088404
# 3  1.737292   0.508827     0.689996  0.038065 -0.912641   -0.088404
# 4 -0.391966  -1.454961    -0.765379 -0.176725 -0.912641   -0.088404
#
#    condition     grade  sqft_basement    yr_old  bedrooms^2  \
# 0  -0.631637  1.148808       0.366699 -1.189796    0.354794
# 1  -0.631637 -0.557812       0.071090 -0.508042   -0.303425
# 2   0.906943 -0.557812       0.207525 -0.405779   -0.303425
# 3   0.906943  0.295498       1.503659  0.139623    1.201074
# 4   0.906943 -0.557812      -0.656564  0.275974   -0.303425
#
#    bedrooms bathrooms  bedrooms sqft_living  bedrooms sqft_lot  \
# 0            1.549596              1.415904          -0.203170
# 1           -0.173595             -0.531748          -0.216494
# 2           -0.530117             -0.568768          -0.174758
# 3            1.193073              1.239032           0.208046
# 4           -1.064900             -0.685997          -0.193911
#
#    bedrooms floors  bedrooms waterfront  bedrooms condition  bedrooms grade  \
# 0         1.153001             -0.08414            0.122370        1.045154
# 1        -0.850686             -0.08414           -0.617332       -0.549392
# 2        -0.850686             -0.08414            0.122370       -0.549392
# 3        -0.049211             -0.08414            2.094909        1.470366
# 4        -0.850686             -0.08414            0.122370       -0.549392
#
#    bedrooms sqft_basement  bedrooms yr_old  bathrooms^2  \
# 0                0.375728        -0.995655     1.994739
# 1               -0.072690        -0.537108     0.005893
# 2                0.023400        -0.452885    -0.547525
# 3                1.950531         0.932113     0.334485
# 4               -0.585168         0.108600    -1.118237
#
#    bathrooms sqft_living  bathrooms sqft_lot  bathrooms floors  \
# 0               1.956110           -0.137427          1.755165
# 1              -0.314377           -0.173922         -0.537295
# 2              -0.549145           -0.170263         -0.778607
# 3               0.472223            0.062069         -0.416640
# 4              -0.898108           -0.234731         -1.140574
#
#    bathrooms waterfront  bathrooms condition  bathrooms grade  \
# 0             -0.082869             1.219869         1.821692
# 1             -0.082869            -0.140650        -0.123484
# 2             -0.082869            -0.049949        -0.555745
# 3             -0.082869             1.038466         0.401405
# 4             -0.082869            -1.138364        -1.204137
#
#    bathrooms sqft_basement  bathrooms yr_old  sqft_living^2  \
# 0                 0.688627         -0.811984       1.507335
# 1                 0.014249         -0.272609      -0.479188
# 2                -0.029132         -0.449524      -0.516467
# 3                 1.319624          0.681006       0.420390
# 4                -0.553648         -0.544454      -0.625296
#
#    sqft_living sqft_lot  sqft_living floors  sqft_living waterfront  \
# 0             -0.135393            1.776440               -0.081054
# 1             -0.198543           -0.748674               -0.081054
# 2             -0.177494           -0.775973               -0.081054
# 3              0.051601           -0.261850               -0.081054
# 4             -0.198970           -0.862418               -0.081054
#
#    sqft_living condition  sqft_living grade  sqft_living sqft_basement  \
# 0               1.138966           1.559741                   0.537134
# 1              -0.655685          -0.526546                  -0.157371
# 2              -0.231439          -0.568471                  -0.109754
# 3               1.148122           0.490644                   1.139961
# 4              -0.463401          -0.701235                  -0.488529
#
#    sqft_living yr_old  sqft_lot^2  sqft_lot floors  sqft_lot waterfront  \
# 0           -0.743765   -0.060112        -0.166060             -0.04272
# 1           -0.569874   -0.059707        -0.226611             -0.04272
# 2           -0.524983   -0.058746        -0.196759             -0.04272
# 3            0.760613   -0.052524        -0.081422             -0.04272
# 4           -0.192007   -0.059221        -0.210459             -0.04272
#
#    sqft_lot condition  sqft_lot grade  sqft_lot sqft_basement  \
# 0           -0.240923       -0.203361               -0.088569
# 1           -0.217820       -0.211462               -0.101910
# 2           -0.115696       -0.170373               -0.055298
# 3            0.106623        0.035112                0.439429
# 4           -0.142103       -0.189229               -0.183586
#
#    sqft_lot yr_old  floors^2  floors waterfront  floors condition  \
# 0        -0.257576  0.806037          -0.083652          0.564396
# 1        -0.193387 -0.834648          -0.083652         -1.133460
# 2        -0.152438 -0.834648          -0.083652         -0.567508
# 3         0.092294 -0.834648          -0.083652         -0.567508
# 4        -0.098340 -0.834648          -0.083652         -0.567508
#
#    floors grade  floors sqft_basement  floors yr_old  waterfront^2  \
# 0      1.175753              0.849902      -0.918494     -0.088404
# 1     -0.886060             -0.086267      -0.705497     -0.088404
# 2     -0.886060              0.010578      -0.634499     -0.088404
# 3     -0.698623              0.930606      -0.255838     -0.088404
# 4     -0.886060             -0.602774      -0.161173     -0.088404
#
#    waterfront condition  waterfront grade  waterfront sqft_basement  \
# 0             -0.086653         -0.086699                 -0.060006
# 1             -0.086653         -0.086699                 -0.060006
# 2             -0.086653         -0.086699                 -0.060006
# 3             -0.086653         -0.086699                 -0.060006
# 4             -0.086653         -0.086699                 -0.060006
#
#    waterfront yr_old  condition^2  condition grade  condition sqft_basement  \
# 0          -0.079524    -0.623341         0.174356                 0.194189
# 1          -0.079524    -0.623341        -0.865283                -0.044317
# 2          -0.079524     0.805326         0.347629                 0.298153
# 3          -0.079524     0.805326         1.040722                 1.692497
# 4          -0.079524     0.805326         0.347629                -0.631409
#
#    condition yr_old   grade^2  grade sqft_basement  grade yr_old  \
# 0         -1.105372  1.101770             0.470012     -1.149596
# 1         -0.597044 -0.573332            -0.014643     -0.577627
# 2         -0.232742 -0.573332             0.097818     -0.475836
# 3          0.309474  0.211872             1.420580      0.309409
# 4          0.445028 -0.573332            -0.614438      0.202771
#
#    sqft_basement^2  sqft_basement yr_old  yr_old^2  bedrooms^3  \
# 0        -0.120659             -0.386752 -0.880020    0.054077
# 1        -0.283289             -0.194699 -0.620353   -0.079682
# 2        -0.215053             -0.078772 -0.560073   -0.079682
# 3         1.016619              1.257480 -0.144605    0.274599
# 4        -0.449657             -0.578032 -0.016008   -0.079682
#
#    bedrooms^2 bathrooms  bedrooms^2 sqft_living  bedrooms^2 sqft_lot  \
# 0              0.972922                0.944975            -0.172941
# 1             -0.286376               -0.465947            -0.217381
# 2             -0.444889               -0.483760            -0.186914
# 3              1.201885                1.276841             0.362072
# 4             -0.682658               -0.540171            -0.200896
#
#    bedrooms^2 floors  bedrooms^2 waterfront  bedrooms^2 condition  \
# 0           0.826007              -0.074846              0.127075
# 1          -0.618669              -0.074846             -0.309354
# 2          -0.618669              -0.074846             -0.122313
# 3           0.386323              -0.074846              1.207757
# 4          -0.618669              -0.074846             -0.122313
#
#    bedrooms^2 grade  bedrooms^2 sqft_basement  bedrooms^2 yr_old  \
# 0          0.578430                  0.264504          -0.468257
# 1         -0.399966                 -0.154877          -0.335644
# 2         -0.399966                 -0.102455          -0.300881
# 3          1.254852                  1.871160           0.914528
# 4         -0.399966                 -0.434465          -0.069129
#
#    bedrooms bathrooms^2  bedrooms bathrooms sqft_living  \
# 0              1.684883                        1.620696
# 1             -0.191826                       -0.379672
# 2             -0.524846                       -0.520308
# 3              0.699698                        0.779428
# 4             -0.868274                       -0.729351
#
#    bedrooms bathrooms sqft_lot  bedrooms bathrooms floors  \
# 0                    -0.110467                   1.705275
# 1                    -0.178490                  -0.567811
# 2                    -0.175757                  -0.728264
# 3                     0.178649                   0.047259
# 4                    -0.223910                  -0.968944
#
#    bedrooms bathrooms waterfront  bedrooms bathrooms condition  \
# 0                      -0.076277                      1.125926
# 1                      -0.076277                     -0.342073
# 2                      -0.076277                     -0.291453
# 3                      -0.076277                      1.665880
# 4                      -0.076277                     -0.898901
#
#    bedrooms bathrooms grade  bedrooms bathrooms sqft_basement  \
# 0                  1.614952                          0.596151
# 1                 -0.315164                         -0.103415
# 2                 -0.572513                         -0.131297
# 3                  0.977707                          1.538200
# 4                 -0.958536                         -0.468407
#
#    bedrooms bathrooms yr_old  bedrooms sqft_living^2  \
# 0                  -0.549770                1.257686
# 1                  -0.339399               -0.456888
# 2                  -0.456483               -0.479549
# 3                   1.243614                0.663533
# 4                  -0.519309               -0.545702
#
#    bedrooms sqft_living sqft_lot  bedrooms sqft_living floors  \
# 0                      -0.110433                     1.594268
# 1                      -0.189972                    -0.676564
# 2                      -0.174725                    -0.693717
# 3                       0.149113                     0.143909
# 4                      -0.190281                    -0.748034
#
#    bedrooms sqft_living waterfront  bedrooms sqft_living condition  \
# 0                        -0.075402                        1.028632
# 1                        -0.075402                       -0.622840
# 2                        -0.075402                       -0.380438
# 3                        -0.075402                        1.663411
# 4                        -0.075402                       -0.512974
#
#    bedrooms sqft_living grade  bedrooms sqft_living sqft_basement  \
# 0                    1.385011                            0.454203
# 1                   -0.541680                           -0.200313
# 2                   -0.567231                           -0.170242
# 3                    0.954289                            1.304626
# 4                   -0.648144                           -0.409450
#
#    bedrooms sqft_living yr_old  bedrooms sqft_lot^2  bedrooms sqft_lot floors  \
# 0                    -0.506630            -0.055677                 -0.138547
# 1                    -0.528368            -0.055585                 -0.228094
# 2                    -0.499191            -0.054802                 -0.204135
# 3                     1.257744            -0.045135                  0.015616
# 4                    -0.282773            -0.055189                 -0.215130
#
#    bedrooms sqft_lot waterfront  bedrooms sqft_lot condition  \
# 0                     -0.043636                    -0.210300
# 1                     -0.043636                    -0.221514
# 2                     -0.043636                    -0.138390
# 3                     -0.043636                     0.291190
# 4                     -0.043636                    -0.159884
#
#    bedrooms sqft_lot grade  bedrooms sqft_lot sqft_basement  \
# 0                -0.176755                        -0.071984
# 1                -0.220237                        -0.100347
# 2                -0.186683                        -0.070977
# 3                 0.184687                         0.502458
# 4                -0.202081                        -0.151811
#
#    bedrooms sqft_lot yr_old  bedrooms floors^2  bedrooms floors waterfront  \
# 0                 -0.235238           1.054996                   -0.078724
# 1                 -0.189391          -0.837892                   -0.078724
# 2                 -0.155440          -0.837892                   -0.078724
# 3                  0.255590          -0.546678                   -0.078724
# 4                 -0.110588          -0.837892                   -0.078724
#
#    bedrooms floors condition  bedrooms floors grade  \
# 0                   0.807401               1.303183
# 1                  -0.967189              -0.824997
# 2                  -0.612271              -0.824997
# 3                   0.334177              -0.032146
# 4                  -0.612271              -0.824997
#
#    bedrooms floors sqft_basement  bedrooms floors yr_old  \
# 0                       0.778843               -0.671137
# 1                      -0.172087               -0.642385
# 2                      -0.107251               -0.590633
# 3                       1.193073                0.260411
# 4                      -0.517879               -0.245615
#
#    bedrooms waterfront^2  bedrooms waterfront condition  \
# 0               -0.08414                      -0.082639
# 1               -0.08414                      -0.082639
# 2               -0.08414                      -0.082639
# 3               -0.08414                      -0.082639
# 4               -0.08414                      -0.082639
#
#    bedrooms waterfront grade  bedrooms waterfront sqft_basement  \
# 0                  -0.082053                           -0.05677
# 1                  -0.082053                           -0.05677
# 2                  -0.082053                           -0.05677
# 3                  -0.082053                           -0.05677
# 4                  -0.082053                           -0.05677
#
#    bedrooms waterfront yr_old  bedrooms condition^2  bedrooms condition grade  \
# 0                   -0.076003             -0.220073                  0.527016
# 1                   -0.076003             -0.640206                 -0.719873
# 2                   -0.076003              0.340105                 -0.137992
# 3                   -0.076003              1.833911                  1.967864
# 4                   -0.076003              0.340105                 -0.137992
#
#    bedrooms condition sqft_basement  bedrooms condition yr_old  \
# 0                          0.212854                  -0.934366
# 1                         -0.150537                  -0.595905
# 2                          0.091724                  -0.298889
# 3                          2.174013                   1.064161
# 4                         -0.565841                   0.253699
#
#    bedrooms grade^2  bedrooms grade sqft_basement  bedrooms grade yr_old  \
# 0          1.124650                      0.455673              -0.895397
# 1         -0.592139                     -0.128146              -0.580053
# 2         -0.592139                     -0.050550              -0.502145
# 3          1.085853                      1.798210               1.088179
# 4         -0.592139                     -0.541992               0.017246
#
#    bedrooms sqft_basement^2  bedrooms sqft_basement yr_old  bedrooms yr_old^2  \
# 0                 -0.103707                      -0.339155          -0.806804
# 1                 -0.281168                      -0.246043          -0.593142
# 2                 -0.236697                      -0.161905          -0.541040
# 3                  1.203072                       1.696049           0.263375
# 4                 -0.389593                      -0.524259          -0.070789
#
#    bathrooms^3  bathrooms^2 sqft_living  bathrooms^2 sqft_lot  \
# 0     1.856950                 1.784763             -0.058820
# 1    -0.120237                -0.267814             -0.135540
# 2    -0.498994                -0.465671             -0.150846
# 3     0.145677                 0.227619              0.030809
# 4    -0.772758                -0.662630             -0.194356
#
#    bathrooms^2 floors  bathrooms^2 waterfront  bathrooms^2 condition  \
# 0            2.017652               -0.073041               1.641343
# 1           -0.424460               -0.073041              -0.141093
# 2           -0.675738               -0.073041              -0.383917
# 3           -0.275263               -0.073041               0.670045
# 4           -0.934869               -0.073041              -1.065893
#
#    bathrooms^2 grade  bathrooms^2 sqft_basement  bathrooms^2 yr_old  \
# 0           1.930104                   0.761100           -0.275235
# 1          -0.163033                  -0.057479           -0.152927
# 2          -0.554732                  -0.153427           -0.444054
# 3           0.244403                   0.850476            0.704608
# 4          -0.958670                  -0.398160           -0.720367
#
#    bathrooms sqft_living^2  bathrooms sqft_living sqft_lot  \
# 0                 1.409479                       -0.061465
# 1                -0.333666                       -0.142455
# 2                -0.407813                       -0.142857
# 3                 0.211902                        0.022195
# 4                -0.515134                       -0.167094
#
#    bathrooms sqft_living floors  bathrooms sqft_living waterfront  \
# 0                      1.991087                         -0.072377
# 1                     -0.527311                         -0.072377
# 2                     -0.635263                         -0.072377
# 3                     -0.165612                         -0.072377
# 4                     -0.795725                         -0.072377
#
#    bathrooms sqft_living condition  bathrooms sqft_living grade  \
# 0                         1.610991                     1.755174
# 1                        -0.415299                    -0.368351
# 2                        -0.416248                    -0.524799
# 3                         0.799108                     0.319813
# 4                        -0.831489                    -0.757345
#
#    bathrooms sqft_living sqft_basement  bathrooms sqft_living yr_old  \
# 0                             0.582339                     -0.240512
# 1                            -0.142645                     -0.370864
# 2                            -0.163607                     -0.478651
# 3                             0.705026                      0.818806
# 4                            -0.332537                     -0.579089
#
#    bathrooms sqft_lot^2  bathrooms sqft_lot floors  \
# 0             -0.062430                  -0.079597
# 1             -0.062509                  -0.185604
# 2             -0.062065                  -0.183667
# 3             -0.054712                  -0.060656
# 4             -0.062985                  -0.217800
#
#    bathrooms sqft_lot waterfront  bathrooms sqft_lot condition  \
# 0                      -0.040756                     -0.154894
# 1                      -0.040756                     -0.187267
# 2                      -0.040756                     -0.145321
# 3                      -0.040756                      0.129464
# 4                      -0.040756                     -0.221568
#
#    bathrooms sqft_lot grade  bathrooms sqft_lot sqft_basement  \
# 0                 -0.111285                         -0.040203
# 1                 -0.172229                         -0.073796
# 2                 -0.169551                         -0.064599
# 3                  0.038458                          0.236368
# 4                 -0.216732                         -0.115287
#
#    bathrooms sqft_lot yr_old  bathrooms floors^2  bathrooms floors waterfront  \
# 0                  -0.255709            1.462543                    -0.076764
# 1                  -0.196715           -0.683458                    -0.076764
# 2                  -0.182785           -0.774777                    -0.076764
# 3                   0.194637           -0.637798                    -0.076764
# 4                  -0.206555           -0.911756                    -0.076764
#
#    bathrooms floors condition  bathrooms floors grade  \
# 0                    1.481484                1.792621
# 1                   -0.662545               -0.578455
# 2                   -0.624930               -0.754090
# 3                   -0.173556               -0.365184
# 4                   -1.076305               -1.017543
#
#    bathrooms floors sqft_basement  bathrooms floors yr_old  \
# 0                        1.040512                -0.423450
# 1                       -0.115100                -0.494107
# 2                       -0.141256                -0.594002
# 3                        0.671953                 0.044347
# 4                       -0.457503                -0.647603
#
#    bathrooms waterfront^2  bathrooms waterfront condition  \
# 0               -0.082869                       -0.081524
# 1               -0.082869                       -0.081524
# 2               -0.082869                       -0.081524
# 3               -0.082869                       -0.081524
# 4               -0.082869                       -0.081524
#
#    bathrooms waterfront grade  bathrooms waterfront sqft_basement  \
# 0                   -0.079418                           -0.055191
# 1                   -0.079418                           -0.055191
# 2                   -0.079418                           -0.055191
# 3                   -0.079418                           -0.055191
# 4                   -0.079418                           -0.055191
#
#    bathrooms waterfront yr_old  bathrooms condition^2  \
# 0                    -0.076376               0.503885
# 1                    -0.076376              -0.365225
# 2                    -0.076376               0.233495
# 3                    -0.076376               1.160547
# 4                    -0.076376              -0.693556
#
#    bathrooms condition grade  bathrooms condition sqft_basement  \
# 0                   1.381168                           0.487984
# 1                  -0.330216                          -0.072999
# 2                  -0.266832                           0.036354
# 3                   0.855981                           1.532310
# 4                  -1.027447                          -0.545406
#
#    bathrooms condition yr_old  bathrooms grade^2  \
# 0                   -0.786085           1.670486
# 1                   -0.398181          -0.292292
# 2                   -0.279224          -0.569857
# 3                    0.804839           0.271334
# 4                   -0.370252          -0.986204
#
#    bathrooms grade sqft_basement  bathrooms grade yr_old  \
# 0                       0.714649               -0.639252
# 1                      -0.061483               -0.340889
# 2                      -0.094194               -0.491912
# 3                       1.124593                0.736268
# 4                      -0.489694               -0.572949
#
#    bathrooms sqft_basement^2  bathrooms sqft_basement yr_old  \
# 0                  -0.005556                       -0.250868
# 1                  -0.224439                       -0.175455
# 2                  -0.214235                       -0.171077
# 3                   0.702546                        1.280399
# 4                  -0.329865                       -0.512432
#
#    bathrooms yr_old^2  sqft_living^3  sqft_living^2 sqft_lot  \
# 0           -0.771387       0.963794               -0.066422
# 1           -0.490520      -0.330475               -0.137126
# 2           -0.513014      -0.344698               -0.131797
# 3            0.169790       0.143323                0.004850
# 4           -0.368764      -0.383023               -0.140836
#
#    sqft_living^2 floors  sqft_living^2 waterfront  sqft_living^2 condition  \
# 0              1.560841                 -0.067196                 1.229806
# 1             -0.530984                 -0.067196                -0.535368
# 2             -0.548356                 -0.067196                -0.426738
# 3             -0.111783                 -0.067196                 0.683218
# 4             -0.599070                 -0.067196                -0.555674
#
#    sqft_living^2 grade  sqft_living^2 sqft_basement  sqft_living^2 yr_old  \
# 0             1.320716                     0.379029             -0.229194
# 1            -0.452542                    -0.171379             -0.480786
# 2            -0.477012                    -0.161765             -0.474676
# 3             0.270669                     0.504231              0.714114
# 4            -0.548447                    -0.265927             -0.394076
#
#    sqft_living sqft_lot^2  sqft_living sqft_lot floors  \
# 0               -0.062338                    -0.083059
# 1               -0.062728                    -0.186469
# 2               -0.062201                    -0.175753
# 3               -0.055085                    -0.059121
# 4               -0.062599                    -0.186686
#
#    sqft_living sqft_lot waterfront  sqft_living sqft_lot condition  \
# 0                        -0.043385                       -0.152043
# 1                        -0.043385                       -0.208917
# 2                        -0.043385                       -0.160577
# 3                        -0.043385                        0.114525
# 4                        -0.043385                       -0.186366
#
#    sqft_living sqft_lot grade  sqft_living sqft_lot sqft_basement  \
# 0                   -0.112150                           -0.042205
# 1                   -0.185548                           -0.073892
# 2                   -0.170569                           -0.063489
# 3                    0.025699                            0.162116
# 4                   -0.185852                           -0.094176
#
#    sqft_living sqft_lot yr_old  sqft_living floors^2  \
# 0                    -0.253055              1.581132
# 1                    -0.227974             -0.759975
# 2                    -0.199784             -0.771009
# 3                     0.188152             -0.563197
# 4                    -0.176015             -0.805951
#
#    sqft_living floors waterfront  sqft_living floors condition  \
# 0                      -0.074897                      1.457588
# 1                      -0.074897                     -0.827187
# 2                      -0.074897                     -0.636446
# 3                      -0.074897                     -0.016195
# 4                      -0.074897                     -0.740736
#
#    sqft_living floors grade  sqft_living floors sqft_basement  \
# 0                  1.661364                          0.790282
# 1                 -0.687775                         -0.195642
# 2                 -0.706317                         -0.168350
# 3                 -0.237902                          0.547931
# 4                 -0.765035                         -0.385447
#
#    sqft_living floors yr_old  sqft_living waterfront^2  \
# 0                  -0.373474                 -0.081054
# 1                  -0.617972                 -0.081054
# 2                  -0.593480                 -0.081054
# 3                   0.107961                 -0.081054
# 4                  -0.411803                 -0.081054
#
#    sqft_living waterfront condition  sqft_living waterfront grade  \
# 0                         -0.079904                     -0.076187
# 1                         -0.079904                     -0.076187
# 2                         -0.079904                     -0.076187
# 3                         -0.079904                     -0.076187
# 4                         -0.079904                     -0.076187
#
#    sqft_living waterfront sqft_basement  sqft_living waterfront yr_old  \
# 0                               -0.0499                      -0.076613
# 1                               -0.0499                      -0.076613
# 2                               -0.0499                      -0.076613
# 3                               -0.0499                      -0.076613
# 4                               -0.0499                      -0.076613
#
#    sqft_living condition^2  sqft_living condition grade  \
# 0                 0.518903                     1.179845
# 1                -0.688084                    -0.642947
# 2                 0.026939                    -0.360080
# 3                 1.264033                     0.873721
# 4                -0.181067                    -0.514741
#
#    sqft_living condition sqft_basement  sqft_living condition yr_old  \
# 0                             0.372376                     -0.730669
# 1                            -0.207838                     -0.604365
# 2                            -0.062577                     -0.368193
# 3                             1.329497                      0.876848
# 4                            -0.484499                     -0.045721
#
#    sqft_living grade^2  sqft_living grade sqft_basement  \
# 0             1.379832                         0.533715
# 1            -0.521114                        -0.181145
# 2            -0.547611                        -0.146676
# 3             0.316431                         0.926358
# 4            -0.631519                        -0.420860
#
#    sqft_living grade yr_old  sqft_living sqft_basement^2  \
# 0                 -0.568800                    -0.037606
# 1                 -0.571910                    -0.216163
# 2                 -0.535417                    -0.197099
# 3                  0.756640                     0.507497
# 4                 -0.264727                    -0.269377
#
#    sqft_living sqft_basement yr_old  sqft_living yr_old^2  sqft_lot^3  \
# 0                         -0.250898             -0.748087   -0.026726
# 1                         -0.271082             -0.575579   -0.026723
# 2                         -0.219204             -0.537712   -0.026714
# 3                          1.141997              0.214330   -0.026619
# 4                         -0.474944             -0.201065   -0.026719
#
#    sqft_lot^2 floors  sqft_lot^2 waterfront  sqft_lot^2 condition  \
# 0          -0.062960              -0.011147             -0.055945
# 1          -0.063279              -0.011147             -0.055610
# 2          -0.062631              -0.011147             -0.054199
# 3          -0.058440              -0.011147             -0.047344
# 4          -0.062951              -0.011147             -0.054721
#
#    sqft_lot^2 grade  sqft_lot^2 sqft_basement  sqft_lot^2 yr_old  \
# 0         -0.063799                 -0.042556          -0.033206
# 1         -0.063659                 -0.042511          -0.032809
# 2         -0.062790                 -0.041225          -0.032327
# 3         -0.056067                 -0.020309          -0.027750
# 4         -0.063219                 -0.043705          -0.032073
#
#    sqft_lot floors^2  sqft_lot floors waterfront  sqft_lot floors condition  \
# 0          -0.111771                   -0.052572                  -0.182159
# 1          -0.219486                   -0.052572                  -0.236404
# 2          -0.204433                   -0.052572                  -0.173121
# 3          -0.146275                   -0.052572                  -0.035357
# 4          -0.211341                   -0.052572                  -0.189484
#
#    sqft_lot floors grade  sqft_lot floors sqft_basement  \
# 0              -0.137452                      -0.031467
# 1              -0.216760                      -0.091747
# 2              -0.194057                      -0.065817
# 3              -0.080519                       0.209403
# 4              -0.204476                      -0.137184
#
#    sqft_lot floors yr_old  sqft_lot waterfront^2  \
# 0               -0.258429               -0.04272
# 1               -0.229061               -0.04272
# 2               -0.197007               -0.04272
# 3               -0.005435               -0.04272
# 4               -0.154660               -0.04272
#
#    sqft_lot waterfront condition  sqft_lot waterfront grade  \
# 0                       -0.04021                  -0.044463
# 1                       -0.04021                  -0.044463
# 2                       -0.04021                  -0.044463
# 3                       -0.04021                  -0.044463
# 4                       -0.04021                  -0.044463
#
#    sqft_lot waterfront sqft_basement  sqft_lot waterfront yr_old  \
# 0                          -0.029997                   -0.042316
# 1                          -0.029997                   -0.042316
# 2                          -0.029997                   -0.042316
# 3                          -0.029997                   -0.042316
# 4                          -0.029997                   -0.042316
#
#    sqft_lot condition^2  sqft_lot condition grade  \
# 0             -0.239453                 -0.218817
# 1             -0.221131                 -0.226019
# 2             -0.077789                 -0.139571
# 3              0.157293                  0.104032
# 4             -0.105712                 -0.161925
#
#    sqft_lot condition sqft_basement  sqft_lot condition yr_old  \
# 0                         -0.101915                  -0.245876
# 1                         -0.113158                  -0.194472
# 2                         -0.037838                  -0.126493
# 3                          0.518073                   0.134823
# 4                         -0.181991                  -0.068730
#
#    sqft_lot grade^2  sqft_lot grade sqft_basement  sqft_lot grade yr_old  \
# 0         -0.171766                     -0.071508              -0.281965
# 1         -0.207202                     -0.100933              -0.223374
# 2         -0.176088                     -0.067058              -0.180960
# 3          0.019957                      0.357173               0.128240
# 4         -0.190367                     -0.160292              -0.124927
#
#    sqft_lot sqft_basement^2  sqft_lot sqft_basement yr_old  sqft_lot yr_old^2  \
# 0                 -0.079331                      -0.159898          -0.184332
# 1                 -0.086937                      -0.126088          -0.154975
# 2                 -0.076589                      -0.084478          -0.135606
# 3                  0.171953                       0.524708           0.031293
# 4                 -0.098898                      -0.183665          -0.070949
#
#    floors^3  floors^2 waterfront  floors^2 condition  floors^2 grade  \
# 0  0.625821            -0.073397            0.641973        0.980355
# 1 -0.722282            -0.073397           -0.922782       -0.825156
# 2 -0.722282            -0.073397           -0.748921       -0.825156
# 3 -0.722282            -0.073397           -0.748921       -0.762897
# 4 -0.722282            -0.073397           -0.748921       -0.825156
#
#    floors^2 sqft_basement  floors^2 yr_old  floors waterfront^2  \
# 0                1.096439        -0.550742            -0.083652
# 1               -0.195267        -0.706657            -0.083652
# 2               -0.142901        -0.670676            -0.083652
# 3                0.354581        -0.478781            -0.083652
# 4               -0.474555        -0.430807            -0.083652
#
#    floors waterfront condition  floors waterfront grade  \
# 0                    -0.083524                -0.080354
# 1                    -0.083524                -0.080354
# 2                    -0.083524                -0.080354
# 3                    -0.083524                -0.080354
# 4                    -0.083524                -0.080354
#
#    floors waterfront sqft_basement  floors waterfront yr_old  \
# 0                         -0.05648                 -0.078078
# 1                         -0.05648                 -0.078078
# 2                         -0.05648                 -0.078078
# 3                         -0.05648                 -0.078078
# 4                         -0.05648                 -0.078078
#
#    floors condition^2  floors condition grade  floors condition sqft_basement  \
# 0            0.087844                0.870139                        0.617844
# 1           -1.063913               -1.056352                       -0.161657
# 2           -0.168102               -0.647703                        0.089217
# 3           -0.168102               -0.414189                        1.110631
# 4           -0.168102               -0.647703                       -0.591726
#
#    floors condition yr_old  floors grade^2  floors grade sqft_basement  \
# 0                -0.872654        1.224565                    0.895476
# 1                -0.714830       -0.816060                   -0.142665
# 2                -0.463479       -0.816060                   -0.068259
# 3                -0.089376       -0.545181                    0.806898
# 4                 0.004149       -0.816060                   -0.539497
#
#    floors grade yr_old  floors sqft_basement^2  floors sqft_basement yr_old  \
# 0            -0.781664                0.050486                    -0.242094
# 1            -0.724025               -0.274954                    -0.241538
# 2            -0.660318               -0.229783                    -0.158106
# 3            -0.168871                0.585537                     0.803581
# 4            -0.235611               -0.385083                    -0.517418
#
#    floors yr_old^2  waterfront^3  waterfront^2 condition  waterfront^2 grade  \
# 0        -0.745200     -0.088404               -0.086653           -0.086699
# 1        -0.596390     -0.088404               -0.086653           -0.086699
# 2        -0.556031     -0.088404               -0.086653           -0.086699
# 3        -0.277865     -0.088404               -0.086653           -0.086699
# 4        -0.191767     -0.088404               -0.086653           -0.086699
#
#    waterfront^2 sqft_basement  waterfront^2 yr_old  waterfront condition^2  \
# 0                   -0.060006            -0.079524               -0.081503
# 1                   -0.060006            -0.079524               -0.081503
# 2                   -0.060006            -0.079524               -0.081503
# 3                   -0.060006            -0.079524               -0.081503
# 4                   -0.060006            -0.079524               -0.081503
#
#    waterfront condition grade  waterfront condition sqft_basement  \
# 0                   -0.085531                           -0.059315
# 1                   -0.085531                           -0.059315
# 2                   -0.085531                           -0.059315
# 3                   -0.085531                           -0.059315
# 4                   -0.085531                           -0.059315
#
#    waterfront condition yr_old  waterfront grade^2  \
# 0                    -0.076576           -0.082382
# 1                    -0.076576           -0.082382
# 2                    -0.076576           -0.082382
# 3                    -0.076576           -0.082382
# 4                    -0.076576           -0.082382
#
#    waterfront grade sqft_basement  waterfront grade yr_old  \
# 0                       -0.056858                -0.081114
# 1                       -0.056858                -0.081114
# 2                       -0.056858                -0.081114
# 3                       -0.056858                -0.081114
# 4                       -0.056858                -0.081114
#
#    waterfront sqft_basement^2  waterfront sqft_basement yr_old  \
# 0                   -0.045141                        -0.058196
# 1                   -0.045141                        -0.058196
# 2                   -0.045141                        -0.058196
# 3                   -0.045141                        -0.058196
# 4                   -0.045141                        -0.058196
#
#    waterfront yr_old^2  condition^3  condition^2 grade  \
# 0            -0.068388    -0.602588          -0.280035
# 1            -0.068388    -0.602588          -0.764356
# 2            -0.068388     0.687781           0.554073
# 3            -0.068388     0.687781           0.984580
# 4            -0.068388     0.687781           0.554073
#
#    condition^2 sqft_basement  condition^2 yr_old  condition grade^2  \
# 0                   0.031378           -0.946765           0.583796
# 1                  -0.144003           -0.610746          -0.806749
# 2                   0.335670           -0.116051          -0.096991
# 3                   1.702738            0.361843           0.772099
# 4                  -0.575708            0.481317          -0.096991
#
#    condition grade sqft_basement  condition grade yr_old  \
# 0                       0.290158               -1.064856
# 1                      -0.106344               -0.645739
# 2                       0.179897               -0.289371
# 3                       1.622785                0.477827
# 4                      -0.597043                0.373640
#
#    condition sqft_basement^2  condition sqft_basement yr_old  \
# 0                  -0.172090                       -0.397497
# 1                  -0.304646                       -0.251486
# 2                  -0.185289                       -0.036827
# 3                   1.153250                        1.317716
# 4                  -0.440248                       -0.542920
#
#    condition yr_old^2   grade^3  grade^2 sqft_basement  grade^2 yr_old  \
# 0           -0.833203  1.021853               0.525170       -1.013494
# 1           -0.631128 -0.569219              -0.088304       -0.621971
# 2           -0.491520 -0.569219              -0.001467       -0.530325
# 3           -0.060428  0.127390               1.244385        0.426038
# 4            0.073006 -0.569219              -0.551437        0.080650
#
#    grade sqft_basement^2  grade sqft_basement yr_old  grade yr_old^2  \
# 0              -0.078671                   -0.343806       -0.875141
# 1              -0.270905                   -0.222867       -0.630570
# 2              -0.219791                   -0.120829       -0.571358
# 3               0.859728                    1.286129       -0.054801
# 4              -0.395527                   -0.560273       -0.036929
#
#    sqft_basement^3  sqft_basement^2 yr_old  sqft_basement yr_old^2  yr_old^3
# 0        -0.191060               -0.372419               -0.441506 -0.665715
# 1        -0.238977               -0.342400               -0.321248 -0.581847
# 2        -0.220827               -0.287390               -0.258637 -0.553813
# 3         0.438108                0.987530                0.661210 -0.301276
# 4        -0.265883               -0.443036               -0.467381 -0.205609

# %% [markdown]
# ***I created this function just in case I lose track of what features I have and I need to reset it***

# %%
def reset_data():
    df = pd.read_csv('kc_house_data.csv',index_col='id')
    df['yr_old']=2017 - df['yr_built']

    df = df[['price','bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
           'floors', 'waterfront', 'condition', 'grade',
           'sqft_basement', 'yr_old']]
    df = df[df.price < 4000000]
    target = df.price
    features = df[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
           'floors', 'waterfront', 'condition', 'grade',
           'sqft_basement', 'yr_old']]
    poly = PolynomialFeatures(degree=3, include_bias=False)
    poly.fit(features)
    column_names = poly.get_feature_names(features.columns)
    df_poly= pd.DataFrame(poly.transform(features), columns=column_names)

    X_train, X_test, y_train, y_test = train_test_split(df_poly, target, random_state=34,test_size=0.2)
    poly = PolynomialFeatures(degree=3, include_bias=False)
    poly.fit(features)
    column_names = poly.get_feature_names(features.columns)
    df_poly= pd.DataFrame(poly.transform(features), columns=column_names)

    X_train, X_test, y_train, y_test = train_test_split(df_poly, target, random_state=34,test_size=0.2)
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train =pd.DataFrame(data=scaler.transform(X_train), columns=column_names)
    X_test =pd.DataFrame(data=scaler.transform(X_test), columns=column_names)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ***Here I am calling reset_data and assigning the returned values to specific variables***

# %%
X_train, X_test, y_train, y_test=  reset_data()

# %% [markdown]
# ***Let's fit a baseline model with all of the variables***

# %%
lm = linear_model.LinearRegression()
lm.fit(X_train, y_train)
y_train_pred = lm.predict(X_train)
y_pred = lm.predict(X_test)
baseline_train_rmse = metrics.mean_absolute_error(y_train, y_train_pred)
baseline_test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Training Error: '+ str(baseline_train_rmse) )
print('Testing Error: '+ str(baseline_test_rmse) )
# Out:
# Training Error: 123141.87401184587
# Testing Error: 197456.5048648691

# %% [markdown]
# ***Here I divided the Eorrs by the standard deviation to bring it down to a scale similiar to a Z-score***

# %%
print('Training Error in Z-score: '+ str(baseline_train_rmse/y_train.std()) )
print('Testing Error in Z-score: '+ str(baseline_test_rmse/y_train.std()) )
# Out:
# Training Error in Z-score: 0.35226795996778343
# Testing Error in Z-score: 0.5648574110901131

# %% [markdown]
# ***Plot the residuals after fitting a linear model***

# %%
sns.residplot(y_train_pred, y_train, lowess=True, color="g")

# %% [markdown]
# ### Based on this residual plot how might we want to transform our data?

# %% [markdown]
# ***Plot to compare the size of all of our coefficients***

# %%
coef = pd.DataFrame(data=lm.coef_ ).T
coef.columns = column_names

model_coef = coef.T.sort_values(by=0).T
model_coef.plot(kind='bar', title='Modal Coefficients', legend=False, figsize=(16,8),)

# %% [markdown]
# ## Types of Feature Selection
#
# * Filter Methods
# * Wrapper Methods
# * Embedded Methods

# %% [markdown]
# # Filter Methods
# Filter feature selection methods apply a statistical measure to assign a scoring to each feature. The features are ranked by the score and either selected to be kept or removed from the dataset. The methods are often univariate and consider the feature independently, or with regard to the dependent variable.

# %% [markdown]
# ![alt text](Filter_1.png)

# %% [markdown]
# **Examples:**
# * F-Test
# * Chi squared test
# * Information gain
# * Correlation coefficient scores

# %% [markdown]
# ![alt text](FS1.webp)

# %% [markdown]
# ### Removing Variables based on correlation coefficient

# %%
# Create correlation matrix
corr_matrix = X_train.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper
# Out:
#                                     bedrooms  bathrooms  sqft_living  \
# bedrooms                                 NaN   0.514319     0.574332
# bathrooms                                NaN        NaN     0.750820
# sqft_living                              NaN        NaN          NaN
# sqft_lot                                 NaN        NaN          NaN
# floors                                   NaN        NaN          NaN
# waterfront                               NaN        NaN          NaN
# condition                                NaN        NaN          NaN
# grade                                    NaN        NaN          NaN
# sqft_basement                            NaN        NaN          NaN
# yr_old                                   NaN        NaN          NaN
# bedrooms^2                               NaN        NaN          NaN
# bedrooms bathrooms                       NaN        NaN          NaN
# bedrooms sqft_living                     NaN        NaN          NaN
# bedrooms sqft_lot                        NaN        NaN          NaN
# bedrooms floors                          NaN        NaN          NaN
# bedrooms waterfront                      NaN        NaN          NaN
# bedrooms condition                       NaN        NaN          NaN
# bedrooms grade                           NaN        NaN          NaN
# bedrooms sqft_basement                   NaN        NaN          NaN
# bedrooms yr_old                          NaN        NaN          NaN
# bathrooms^2                              NaN        NaN          NaN
# bathrooms sqft_living                    NaN        NaN          NaN
# bathrooms sqft_lot                       NaN        NaN          NaN
# bathrooms floors                         NaN        NaN          NaN
# bathrooms waterfront                     NaN        NaN          NaN
# bathrooms condition                      NaN        NaN          NaN
# bathrooms grade                          NaN        NaN          NaN
# bathrooms sqft_basement                  NaN        NaN          NaN
# bathrooms yr_old                         NaN        NaN          NaN
# sqft_living^2                            NaN        NaN          NaN
# ...                                      ...        ...          ...
# waterfront condition^2                   NaN        NaN          NaN
# waterfront condition grade               NaN        NaN          NaN
# waterfront condition sqft_basement       NaN        NaN          NaN
# waterfront condition yr_old              NaN        NaN          NaN
# waterfront grade^2                       NaN        NaN          NaN
# waterfront grade sqft_basement           NaN        NaN          NaN
# waterfront grade yr_old                  NaN        NaN          NaN
# waterfront sqft_basement^2               NaN        NaN          NaN
# waterfront sqft_basement yr_old          NaN        NaN          NaN
# waterfront yr_old^2                      NaN        NaN          NaN
# condition^3                              NaN        NaN          NaN
# condition^2 grade                        NaN        NaN          NaN
# condition^2 sqft_basement                NaN        NaN          NaN
# condition^2 yr_old                       NaN        NaN          NaN
# condition grade^2                        NaN        NaN          NaN
# condition grade sqft_basement            NaN        NaN          NaN
# condition grade yr_old                   NaN        NaN          NaN
# condition sqft_basement^2                NaN        NaN          NaN
# condition sqft_basement yr_old           NaN        NaN          NaN
# condition yr_old^2                       NaN        NaN          NaN
# grade^3                                  NaN        NaN          NaN
# grade^2 sqft_basement                    NaN        NaN          NaN
# grade^2 yr_old                           NaN        NaN          NaN
# grade sqft_basement^2                    NaN        NaN          NaN
# grade sqft_basement yr_old               NaN        NaN          NaN
# grade yr_old^2                           NaN        NaN          NaN
# sqft_basement^3                          NaN        NaN          NaN
# sqft_basement^2 yr_old                   NaN        NaN          NaN
# sqft_basement yr_old^2                   NaN        NaN          NaN
# yr_old^3                                 NaN        NaN          NaN
#
#                                     sqft_lot    floors  waterfront  condition  \
# bedrooms                            0.032767  0.176607    0.016390   0.026939
# bathrooms                           0.085243  0.503686    0.046278   0.127160
# sqft_living                         0.174174  0.358567    0.084363   0.060712
# sqft_lot                                 NaN  0.005830    0.022657   0.008068
# floors                                   NaN       NaN    0.018598   0.265653
# waterfront                               NaN       NaN         NaN   0.025365
# condition                                NaN       NaN         NaN        NaN
# grade                                    NaN       NaN         NaN        NaN
# sqft_basement                            NaN       NaN         NaN        NaN
# yr_old                                   NaN       NaN         NaN        NaN
# bedrooms^2                               NaN       NaN         NaN        NaN
# bedrooms bathrooms                       NaN       NaN         NaN        NaN
# bedrooms sqft_living                     NaN       NaN         NaN        NaN
# bedrooms sqft_lot                        NaN       NaN         NaN        NaN
# bedrooms floors                          NaN       NaN         NaN        NaN
# bedrooms waterfront                      NaN       NaN         NaN        NaN
# bedrooms condition                       NaN       NaN         NaN        NaN
# bedrooms grade                           NaN       NaN         NaN        NaN
# bedrooms sqft_basement                   NaN       NaN         NaN        NaN
# bedrooms yr_old                          NaN       NaN         NaN        NaN
# bathrooms^2                              NaN       NaN         NaN        NaN
# bathrooms sqft_living                    NaN       NaN         NaN        NaN
# bathrooms sqft_lot                       NaN       NaN         NaN        NaN
# bathrooms floors                         NaN       NaN         NaN        NaN
# bathrooms waterfront                     NaN       NaN         NaN        NaN
# bathrooms condition                      NaN       NaN         NaN        NaN
# bathrooms grade                          NaN       NaN         NaN        NaN
# bathrooms sqft_basement                  NaN       NaN         NaN        NaN
# bathrooms yr_old                         NaN       NaN         NaN        NaN
# sqft_living^2                            NaN       NaN         NaN        NaN
# ...                                      ...       ...         ...        ...
# waterfront condition^2                   NaN       NaN         NaN        NaN
# waterfront condition grade               NaN       NaN         NaN        NaN
# waterfront condition sqft_basement       NaN       NaN         NaN        NaN
# waterfront condition yr_old              NaN       NaN         NaN        NaN
# waterfront grade^2                       NaN       NaN         NaN        NaN
# waterfront grade sqft_basement           NaN       NaN         NaN        NaN
# waterfront grade yr_old                  NaN       NaN         NaN        NaN
# waterfront sqft_basement^2               NaN       NaN         NaN        NaN
# waterfront sqft_basement yr_old          NaN       NaN         NaN        NaN
# waterfront yr_old^2                      NaN       NaN         NaN        NaN
# condition^3                              NaN       NaN         NaN        NaN
# condition^2 grade                        NaN       NaN         NaN        NaN
# condition^2 sqft_basement                NaN       NaN         NaN        NaN
# condition^2 yr_old                       NaN       NaN         NaN        NaN
# condition grade^2                        NaN       NaN         NaN        NaN
# condition grade sqft_basement            NaN       NaN         NaN        NaN
# condition grade yr_old                   NaN       NaN         NaN        NaN
# condition sqft_basement^2                NaN       NaN         NaN        NaN
# condition sqft_basement yr_old           NaN       NaN         NaN        NaN
# condition yr_old^2                       NaN       NaN         NaN        NaN
# grade^3                                  NaN       NaN         NaN        NaN
# grade^2 sqft_basement                    NaN       NaN         NaN        NaN
# grade^2 yr_old                           NaN       NaN         NaN        NaN
# grade sqft_basement^2                    NaN       NaN         NaN        NaN
# grade sqft_basement yr_old               NaN       NaN         NaN        NaN
# grade yr_old^2                           NaN       NaN         NaN        NaN
# sqft_basement^3                          NaN       NaN         NaN        NaN
# sqft_basement^2 yr_old                   NaN       NaN         NaN        NaN
# sqft_basement yr_old^2                   NaN       NaN         NaN        NaN
# yr_old^3                                 NaN       NaN         NaN        NaN
#
#                                        grade  sqft_basement    yr_old  \
# bedrooms                            0.353560       0.299345  0.153056
# bathrooms                           0.659396       0.274813  0.507626
# sqft_living                         0.761712       0.427659  0.319582
# sqft_lot                            0.111875       0.017077  0.050489
# floors                              0.457742       0.243540  0.489853
# waterfront                          0.071159       0.070190  0.029997
# condition                           0.143701       0.166954  0.362640
# grade                                    NaN       0.164505  0.441203
# sqft_basement                            NaN            NaN  0.132107
# yr_old                                   NaN            NaN       NaN
# bedrooms^2                               NaN            NaN       NaN
# bedrooms bathrooms                       NaN            NaN       NaN
# bedrooms sqft_living                     NaN            NaN       NaN
# bedrooms sqft_lot                        NaN            NaN       NaN
# bedrooms floors                          NaN            NaN       NaN
# bedrooms waterfront                      NaN            NaN       NaN
# bedrooms condition                       NaN            NaN       NaN
# bedrooms grade                           NaN            NaN       NaN
# bedrooms sqft_basement                   NaN            NaN       NaN
# bedrooms yr_old                          NaN            NaN       NaN
# bathrooms^2                              NaN            NaN       NaN
# bathrooms sqft_living                    NaN            NaN       NaN
# bathrooms sqft_lot                       NaN            NaN       NaN
# bathrooms floors                         NaN            NaN       NaN
# bathrooms waterfront                     NaN            NaN       NaN
# bathrooms condition                      NaN            NaN       NaN
# bathrooms grade                          NaN            NaN       NaN
# bathrooms sqft_basement                  NaN            NaN       NaN
# bathrooms yr_old                         NaN            NaN       NaN
# sqft_living^2                            NaN            NaN       NaN
# ...                                      ...            ...       ...
# waterfront condition^2                   NaN            NaN       NaN
# waterfront condition grade               NaN            NaN       NaN
# waterfront condition sqft_basement       NaN            NaN       NaN
# waterfront condition yr_old              NaN            NaN       NaN
# waterfront grade^2                       NaN            NaN       NaN
# waterfront grade sqft_basement           NaN            NaN       NaN
# waterfront grade yr_old                  NaN            NaN       NaN
# waterfront sqft_basement^2               NaN            NaN       NaN
# waterfront sqft_basement yr_old          NaN            NaN       NaN
# waterfront yr_old^2                      NaN            NaN       NaN
# condition^3                              NaN            NaN       NaN
# condition^2 grade                        NaN            NaN       NaN
# condition^2 sqft_basement                NaN            NaN       NaN
# condition^2 yr_old                       NaN            NaN       NaN
# condition grade^2                        NaN            NaN       NaN
# condition grade sqft_basement            NaN            NaN       NaN
# condition grade yr_old                   NaN            NaN       NaN
# condition sqft_basement^2                NaN            NaN       NaN
# condition sqft_basement yr_old           NaN            NaN       NaN
# condition yr_old^2                       NaN            NaN       NaN
# grade^3                                  NaN            NaN       NaN
# grade^2 sqft_basement                    NaN            NaN       NaN
# grade^2 yr_old                           NaN            NaN       NaN
# grade sqft_basement^2                    NaN            NaN       NaN
# grade sqft_basement yr_old               NaN            NaN       NaN
# grade yr_old^2                           NaN            NaN       NaN
# sqft_basement^3                          NaN            NaN       NaN
# sqft_basement^2 yr_old                   NaN            NaN       NaN
# sqft_basement yr_old^2                   NaN            NaN       NaN
# yr_old^3                                 NaN            NaN       NaN
#
#                                     bedrooms^2  bedrooms bathrooms  \
# bedrooms                              0.786782            0.805869
# bathrooms                             0.315740            0.886833
# sqft_living                           0.355990            0.769911
# sqft_lot                              0.019229            0.075293
# floors                                0.100581            0.386420
# waterfront                            0.008089            0.021464
# condition                             0.026814            0.070889
# grade                                 0.203155            0.579320
# sqft_basement                         0.202066            0.330848
# yr_old                                0.069135            0.364522
# bedrooms^2                                 NaN            0.584906
# bedrooms bathrooms                         NaN                 NaN
# bedrooms sqft_living                       NaN                 NaN
# bedrooms sqft_lot                          NaN                 NaN
# bedrooms floors                            NaN                 NaN
# bedrooms waterfront                        NaN                 NaN
# bedrooms condition                         NaN                 NaN
# bedrooms grade                             NaN                 NaN
# bedrooms sqft_basement                     NaN                 NaN
# bedrooms yr_old                            NaN                 NaN
# bathrooms^2                                NaN                 NaN
# bathrooms sqft_living                      NaN                 NaN
# bathrooms sqft_lot                         NaN                 NaN
# bathrooms floors                           NaN                 NaN
# bathrooms waterfront                       NaN                 NaN
# bathrooms condition                        NaN                 NaN
# bathrooms grade                            NaN                 NaN
# bathrooms sqft_basement                    NaN                 NaN
# bathrooms yr_old                           NaN                 NaN
# sqft_living^2                              NaN                 NaN
# ...                                        ...                 ...
# waterfront condition^2                     NaN                 NaN
# waterfront condition grade                 NaN                 NaN
# waterfront condition sqft_basement         NaN                 NaN
# waterfront condition yr_old                NaN                 NaN
# waterfront grade^2                         NaN                 NaN
# waterfront grade sqft_basement             NaN                 NaN
# waterfront grade yr_old                    NaN                 NaN
# waterfront sqft_basement^2                 NaN                 NaN
# waterfront sqft_basement yr_old            NaN                 NaN
# waterfront yr_old^2                        NaN                 NaN
# condition^3                                NaN                 NaN
# condition^2 grade                          NaN                 NaN
# condition^2 sqft_basement                  NaN                 NaN
# condition^2 yr_old                         NaN                 NaN
# condition grade^2                          NaN                 NaN
# condition grade sqft_basement              NaN                 NaN
# condition grade yr_old                     NaN                 NaN
# condition sqft_basement^2                  NaN                 NaN
# condition sqft_basement yr_old             NaN                 NaN
# condition yr_old^2                         NaN                 NaN
# grade^3                                    NaN                 NaN
# grade^2 sqft_basement                      NaN                 NaN
# grade^2 yr_old                             NaN                 NaN
# grade sqft_basement^2                      NaN                 NaN
# grade sqft_basement yr_old                 NaN                 NaN
# grade yr_old^2                             NaN                 NaN
# sqft_basement^3                            NaN                 NaN
# sqft_basement^2 yr_old                     NaN                 NaN
# sqft_basement yr_old^2                     NaN                 NaN
# yr_old^3                                   NaN                 NaN
#
#                                     bedrooms sqft_living  bedrooms sqft_lot  \
# bedrooms                                        0.791687           0.124095
# bathrooms                                       0.718988           0.140660
# sqft_living                                     0.924828           0.235092
# sqft_lot                                        0.133778           0.956015
# floors                                          0.311169           0.018290
# waterfront                                      0.045932           0.017017
# condition                                       0.035068           0.002903
# grade                                           0.653959           0.150236
# sqft_basement                                   0.423296           0.050564
# yr_old                                          0.257502           0.060852
# bedrooms^2                                      0.564568           0.083386
# bedrooms bathrooms                              0.884118           0.159431
# bedrooms sqft_living                                 NaN           0.221589
# bedrooms sqft_lot                                    NaN                NaN
# bedrooms floors                                      NaN                NaN
# bedrooms waterfront                                  NaN                NaN
# bedrooms condition                                   NaN                NaN
# bedrooms grade                                       NaN                NaN
# bedrooms sqft_basement                               NaN                NaN
# bedrooms yr_old                                      NaN                NaN
# bathrooms^2                                          NaN                NaN
# bathrooms sqft_living                                NaN                NaN
# bathrooms sqft_lot                                   NaN                NaN
# bathrooms floors                                     NaN                NaN
# bathrooms waterfront                                 NaN                NaN
# bathrooms condition                                  NaN                NaN
# bathrooms grade                                      NaN                NaN
# bathrooms sqft_basement                              NaN                NaN
# bathrooms yr_old                                     NaN                NaN
# sqft_living^2                                        NaN                NaN
# ...                                                  ...                ...
# waterfront condition^2                               NaN                NaN
# waterfront condition grade                           NaN                NaN
# waterfront condition sqft_basement                   NaN                NaN
# waterfront condition yr_old                          NaN                NaN
# waterfront grade^2                                   NaN                NaN
# waterfront grade sqft_basement                       NaN                NaN
# waterfront grade yr_old                              NaN                NaN
# waterfront sqft_basement^2                           NaN                NaN
# waterfront sqft_basement yr_old                      NaN                NaN
# waterfront yr_old^2                                  NaN                NaN
# condition^3                                          NaN                NaN
# condition^2 grade                                    NaN                NaN
# condition^2 sqft_basement                            NaN                NaN
# condition^2 yr_old                                   NaN                NaN
# condition grade^2                                    NaN                NaN
# condition grade sqft_basement                        NaN                NaN
# condition grade yr_old                               NaN                NaN
# condition sqft_basement^2                            NaN                NaN
# condition sqft_basement yr_old                       NaN                NaN
# condition yr_old^2                                   NaN                NaN
# grade^3                                              NaN                NaN
# grade^2 sqft_basement                                NaN                NaN
# grade^2 yr_old                                       NaN                NaN
# grade sqft_basement^2                                NaN                NaN
# grade sqft_basement yr_old                           NaN                NaN
# grade yr_old^2                                       NaN                NaN
# sqft_basement^3                                      NaN                NaN
# sqft_basement^2 yr_old                               NaN                NaN
# sqft_basement yr_old^2                               NaN                NaN
# yr_old^3                                             NaN                NaN
#
#                                     bedrooms floors  bedrooms waterfront  \
# bedrooms                                   0.680514             0.013902
# bathrooms                                  0.651715             0.060636
# sqft_living                                0.602747             0.098077
# sqft_lot                                   0.019734             0.020564
# floors                                     0.813659             0.022851
# waterfront                                 0.004242             0.951770
# condition                                  0.182602             0.021261
# grade                                      0.534111             0.079718
# sqft_basement                              0.037715             0.077939
# yr_old                                     0.415865             0.025586
# bedrooms^2                                 0.488088             0.009777
# bedrooms bathrooms                         0.747324             0.046336
# bedrooms sqft_living                       0.698050             0.070139
# bedrooms sqft_lot                          0.088341             0.018944
# bedrooms floors                                 NaN             0.025678
# bedrooms waterfront                             NaN                  NaN
# bedrooms condition                              NaN                  NaN
# bedrooms grade                                  NaN                  NaN
# bedrooms sqft_basement                          NaN                  NaN
# bedrooms yr_old                                 NaN                  NaN
# bathrooms^2                                     NaN                  NaN
# bathrooms sqft_living                           NaN                  NaN
# bathrooms sqft_lot                              NaN                  NaN
# bathrooms floors                                NaN                  NaN
# bathrooms waterfront                            NaN                  NaN
# bathrooms condition                             NaN                  NaN
# bathrooms grade                                 NaN                  NaN
# bathrooms sqft_basement                         NaN                  NaN
# bathrooms yr_old                                NaN                  NaN
# sqft_living^2                                   NaN                  NaN
# ...                                             ...                  ...
# waterfront condition^2                          NaN                  NaN
# waterfront condition grade                      NaN                  NaN
# waterfront condition sqft_basement              NaN                  NaN
# waterfront condition yr_old                     NaN                  NaN
# waterfront grade^2                              NaN                  NaN
# waterfront grade sqft_basement                  NaN                  NaN
# waterfront grade yr_old                         NaN                  NaN
# waterfront sqft_basement^2                      NaN                  NaN
# waterfront sqft_basement yr_old                 NaN                  NaN
# waterfront yr_old^2                             NaN                  NaN
# condition^3                                     NaN                  NaN
# condition^2 grade                               NaN                  NaN
# condition^2 sqft_basement                       NaN                  NaN
# condition^2 yr_old                              NaN                  NaN
# condition grade^2                               NaN                  NaN
# condition grade sqft_basement                   NaN                  NaN
# condition grade yr_old                          NaN                  NaN
# condition sqft_basement^2                       NaN                  NaN
# condition sqft_basement yr_old                  NaN                  NaN
# condition yr_old^2                              NaN                  NaN
# grade^3                                         NaN                  NaN
# grade^2 sqft_basement                           NaN                  NaN
# grade^2 yr_old                                  NaN                  NaN
# grade sqft_basement^2                           NaN                  NaN
# grade sqft_basement yr_old                      NaN                  NaN
# grade yr_old^2                                  NaN                  NaN
# sqft_basement^3                                 NaN                  NaN
# sqft_basement^2 yr_old                          NaN                  NaN
# sqft_basement yr_old^2                          NaN                  NaN
# yr_old^3                                        NaN                  NaN
#
#                                     bedrooms condition  bedrooms grade  \
# bedrooms                                      0.823989        0.902414
# bathrooms                                     0.332464        0.676222
# sqft_living                                   0.414250        0.781050
# sqft_lot                                      0.022770        0.077096
# floors                                        0.006524        0.327400
# waterfront                                    0.001870        0.017145
# condition                                     0.561685        0.043719
# grade                                         0.196544        0.704428
# sqft_basement                                 0.337740        0.300973
# yr_old                                        0.081929        0.294127
# bedrooms^2                                    0.703922        0.676243
# bedrooms bathrooms                            0.599970        0.874924
# bedrooms sqft_living                          0.608120        0.909527
# bedrooms sqft_lot                             0.098523        0.164826
# bedrooms floors                               0.438731        0.751318
# bedrooms waterfront                           0.021736        0.044701
# bedrooms condition                                 NaN        0.699791
# bedrooms grade                                     NaN             NaN
# bedrooms sqft_basement                             NaN             NaN
# bedrooms yr_old                                    NaN             NaN
# bathrooms^2                                        NaN             NaN
# bathrooms sqft_living                              NaN             NaN
# bathrooms sqft_lot                                 NaN             NaN
# bathrooms floors                                   NaN             NaN
# bathrooms waterfront                               NaN             NaN
# bathrooms condition                                NaN             NaN
# bathrooms grade                                    NaN             NaN
# bathrooms sqft_basement                            NaN             NaN
# bathrooms yr_old                                   NaN             NaN
# sqft_living^2                                      NaN             NaN
# ...                                                ...             ...
# waterfront condition^2                             NaN             NaN
# waterfront condition grade                         NaN             NaN
# waterfront condition sqft_basement                 NaN             NaN
# waterfront condition yr_old                        NaN             NaN
# waterfront grade^2                                 NaN             NaN
# waterfront grade sqft_basement                     NaN             NaN
# waterfront grade yr_old                            NaN             NaN
# waterfront sqft_basement^2                         NaN             NaN
# waterfront sqft_basement yr_old                    NaN             NaN
# waterfront yr_old^2                                NaN             NaN
# condition^3                                        NaN             NaN
# condition^2 grade                                  NaN             NaN
# condition^2 sqft_basement                          NaN             NaN
# condition^2 yr_old                                 NaN             NaN
# condition grade^2                                  NaN             NaN
# condition grade sqft_basement                      NaN             NaN
# condition grade yr_old                             NaN             NaN
# condition sqft_basement^2                          NaN             NaN
# condition sqft_basement yr_old                     NaN             NaN
# condition yr_old^2                                 NaN             NaN
# grade^3                                            NaN             NaN
# grade^2 sqft_basement                              NaN             NaN
# grade^2 yr_old                                     NaN             NaN
# grade sqft_basement^2                              NaN             NaN
# grade sqft_basement yr_old                         NaN             NaN
# grade yr_old^2                                     NaN             NaN
# sqft_basement^3                                    NaN             NaN
# sqft_basement^2 yr_old                             NaN             NaN
# sqft_basement yr_old^2                             NaN             NaN
# yr_old^3                                           NaN             NaN
#
#                                     bedrooms sqft_basement  bedrooms yr_old  \
# bedrooms                                          0.445174         0.330131
# bathrooms                                         0.319829         0.234596
# sqft_living                                       0.464932         0.056975
# sqft_lot                                          0.023538         0.032334
# floors                                            0.197351         0.345884
# waterfront                                        0.053195         0.020448
# condition                                         0.152288         0.358321
# grade                                             0.187262         0.247743
# sqft_basement                                     0.955732         0.269269
# yr_old                                            0.104817         0.841858
# bedrooms^2                                        0.352386         0.327607
# bedrooms bathrooms                                0.448255         0.014367
# bedrooms sqft_living                              0.534622         0.098781
# bedrooms sqft_lot                                 0.072868         0.003723
# bedrooms floors                                   0.073918         0.068195
# bedrooms waterfront                               0.066813         0.033512
# bedrooms condition                                0.454388         0.485552
# bedrooms grade                                    0.427976         0.136392
# bedrooms sqft_basement                                 NaN         0.315394
# bedrooms yr_old                                        NaN              NaN
# bathrooms^2                                            NaN              NaN
# bathrooms sqft_living                                  NaN              NaN
# bathrooms sqft_lot                                     NaN              NaN
# bathrooms floors                                       NaN              NaN
# bathrooms waterfront                                   NaN              NaN
# bathrooms condition                                    NaN              NaN
# bathrooms grade                                        NaN              NaN
# bathrooms sqft_basement                                NaN              NaN
# bathrooms yr_old                                       NaN              NaN
# sqft_living^2                                          NaN              NaN
# ...                                                    ...              ...
# waterfront condition^2                                 NaN              NaN
# waterfront condition grade                             NaN              NaN
# waterfront condition sqft_basement                     NaN              NaN
# waterfront condition yr_old                            NaN              NaN
# waterfront grade^2                                     NaN              NaN
# waterfront grade sqft_basement                         NaN              NaN
# waterfront grade yr_old                                NaN              NaN
# waterfront sqft_basement^2                             NaN              NaN
# waterfront sqft_basement yr_old                        NaN              NaN
# waterfront yr_old^2                                    NaN              NaN
# condition^3                                            NaN              NaN
# condition^2 grade                                      NaN              NaN
# condition^2 sqft_basement                              NaN              NaN
# condition^2 yr_old                                     NaN              NaN
# condition grade^2                                      NaN              NaN
# condition grade sqft_basement                          NaN              NaN
# condition grade yr_old                                 NaN              NaN
# condition sqft_basement^2                              NaN              NaN
# condition sqft_basement yr_old                         NaN              NaN
# condition yr_old^2                                     NaN              NaN
# grade^3                                                NaN              NaN
# grade^2 sqft_basement                                  NaN              NaN
# grade^2 yr_old                                         NaN              NaN
# grade sqft_basement^2                                  NaN              NaN
# grade sqft_basement yr_old                             NaN              NaN
# grade yr_old^2                                         NaN              NaN
# sqft_basement^3                                        NaN              NaN
# sqft_basement^2 yr_old                                 NaN              NaN
# sqft_basement yr_old^2                                 NaN              NaN
# yr_old^3                                               NaN              NaN
#
#                                     bathrooms^2  bathrooms sqft_living  \
# bedrooms                               0.490193               0.530137
# bathrooms                              0.964188               0.858186
# sqft_living                            0.749553               0.930095
# sqft_lot                               0.098664               0.161991
# floors                                 0.463911               0.395913
# waterfront                             0.052069               0.075954
# condition                              0.127236               0.092864
# grade                                  0.632968               0.726446
# sqft_basement                          0.275434               0.371681
# yr_old                                 0.440793               0.360502
# bedrooms^2                             0.312734               0.338352
# bedrooms bathrooms                     0.891731               0.849921
# bedrooms sqft_living                   0.738534               0.893187
# bedrooms sqft_lot                      0.159595               0.232268
# bedrooms floors                        0.625803               0.613784
# bedrooms waterfront                    0.067484               0.092152
# bedrooms condition                     0.310241               0.359855
# bedrooms grade                         0.660793               0.744224
# bedrooms sqft_basement                 0.332712               0.432587
# bedrooms yr_old                        0.201972               0.123825
# bathrooms^2                                 NaN               0.906157
# bathrooms sqft_living                       NaN                    NaN
# bathrooms sqft_lot                          NaN                    NaN
# bathrooms floors                            NaN                    NaN
# bathrooms waterfront                        NaN                    NaN
# bathrooms condition                         NaN                    NaN
# bathrooms grade                             NaN                    NaN
# bathrooms sqft_basement                     NaN                    NaN
# bathrooms yr_old                            NaN                    NaN
# sqft_living^2                               NaN                    NaN
# ...                                         ...                    ...
# waterfront condition^2                      NaN                    NaN
# waterfront condition grade                  NaN                    NaN
# waterfront condition sqft_basement          NaN                    NaN
# waterfront condition yr_old                 NaN                    NaN
# waterfront grade^2                          NaN                    NaN
# waterfront grade sqft_basement              NaN                    NaN
# waterfront grade yr_old                     NaN                    NaN
# waterfront sqft_basement^2                  NaN                    NaN
# waterfront sqft_basement yr_old             NaN                    NaN
# waterfront yr_old^2                         NaN                    NaN
# condition^3                                 NaN                    NaN
# condition^2 grade                           NaN                    NaN
# condition^2 sqft_basement                   NaN                    NaN
# condition^2 yr_old                          NaN                    NaN
# condition grade^2                           NaN                    NaN
# condition grade sqft_basement               NaN                    NaN
# condition grade yr_old                      NaN                    NaN
# condition sqft_basement^2                   NaN                    NaN
# condition sqft_basement yr_old              NaN                    NaN
# condition yr_old^2                          NaN                    NaN
# grade^3                                     NaN                    NaN
# grade^2 sqft_basement                       NaN                    NaN
# grade^2 yr_old                              NaN                    NaN
# grade sqft_basement^2                       NaN                    NaN
# grade sqft_basement yr_old                  NaN                    NaN
# grade yr_old^2                              NaN                    NaN
# sqft_basement^3                             NaN                    NaN
# sqft_basement^2 yr_old                      NaN                    NaN
# sqft_basement yr_old^2                      NaN                    NaN
# yr_old^3                                    NaN                    NaN
#
#                                     bathrooms sqft_lot  bathrooms floors  \
# bedrooms                                      0.089690          0.375130
# bathrooms                                     0.205620          0.846589
# sqft_living                                   0.277631          0.630734
# sqft_lot                                      0.906968          0.047509
# floors                                        0.051296          0.861267
# waterfront                                    0.024599          0.039186
# condition                                     0.018548          0.235437
# grade                                         0.198819          0.632443
# sqft_basement                                 0.059511          0.009957
# yr_old                                        0.093186          0.558338
# bedrooms^2                                    0.055531          0.228913
# bedrooms bathrooms                            0.187842          0.723833
# bedrooms sqft_living                          0.239561          0.591476
# bedrooms sqft_lot                             0.927164          0.094197
# bedrooms floors                               0.095681          0.845061
# bedrooms waterfront                           0.024790          0.049860
# bedrooms condition                            0.060527          0.162006
# bedrooms grade                                0.161498          0.563506
# bedrooms sqft_basement                        0.076490          0.045947
# bedrooms yr_old                               0.051457          0.341770
# bathrooms^2                                   0.236422          0.829967
# bathrooms sqft_living                         0.305301          0.734731
# bathrooms sqft_lot                                 NaN          0.154041
# bathrooms floors                                   NaN               NaN
# bathrooms waterfront                               NaN               NaN
# bathrooms condition                                NaN               NaN
# bathrooms grade                                    NaN               NaN
# bathrooms sqft_basement                            NaN               NaN
# bathrooms yr_old                                   NaN               NaN
# sqft_living^2                                      NaN               NaN
# ...                                                ...               ...
# waterfront condition^2                             NaN               NaN
# waterfront condition grade                         NaN               NaN
# waterfront condition sqft_basement                 NaN               NaN
# waterfront condition yr_old                        NaN               NaN
# waterfront grade^2                                 NaN               NaN
# waterfront grade sqft_basement                     NaN               NaN
# waterfront grade yr_old                            NaN               NaN
# waterfront sqft_basement^2                         NaN               NaN
# waterfront sqft_basement yr_old                    NaN               NaN
# waterfront yr_old^2                                NaN               NaN
# condition^3                                        NaN               NaN
# condition^2 grade                                  NaN               NaN
# condition^2 sqft_basement                          NaN               NaN
# condition^2 yr_old                                 NaN               NaN
# condition grade^2                                  NaN               NaN
# condition grade sqft_basement                      NaN               NaN
# condition grade yr_old                             NaN               NaN
# condition sqft_basement^2                          NaN               NaN
# condition sqft_basement yr_old                     NaN               NaN
# condition yr_old^2                                 NaN               NaN
# grade^3                                            NaN               NaN
# grade^2 sqft_basement                              NaN               NaN
# grade^2 yr_old                                     NaN               NaN
# grade sqft_basement^2                              NaN               NaN
# grade sqft_basement yr_old                         NaN               NaN
# grade yr_old^2                                     NaN               NaN
# sqft_basement^3                                    NaN               NaN
# sqft_basement^2 yr_old                             NaN               NaN
# sqft_basement yr_old^2                             NaN               NaN
# yr_old^3                                           NaN               NaN
#
#                                     bathrooms waterfront  bathrooms condition  \
# bedrooms                                        0.001536             0.493352
# bathrooms                                       0.080695             0.866487
# sqft_living                                     0.111252             0.667388
# sqft_lot                                        0.022438             0.076845
# floors                                          0.032252             0.326842
# waterfront                                      0.937396             0.057577
# condition                                       0.018701             0.354073
# grade                                           0.096042             0.537865
# sqft_basement                                   0.080954             0.357110
# yr_old                                          0.016662             0.274106
# bedrooms^2                                      0.001827             0.307658
# bedrooms bathrooms                              0.051571             0.788786
# bedrooms sqft_living                            0.071840             0.650927
# bedrooms sqft_lot                               0.019221             0.130658
# ...
# bedrooms bathrooms                                    0.230696
# bedrooms sqft_living                                  0.337369
# bedrooms sqft_lot                                     0.014428
# bedrooms floors                                       0.047556
# bedrooms waterfront                                   0.081734
# bedrooms condition                                    0.354297
# bedrooms grade                                        0.235346
# bedrooms sqft_basement                                0.810193
# bedrooms yr_old                                       0.491020
# bathrooms^2                                           0.157545
# bathrooms sqft_living                                 0.258645
# bathrooms sqft_lot                                    0.015081
# bathrooms floors                                      0.064616
# bathrooms waterfront                                  0.081363
# bathrooms condition                                   0.311116
# bathrooms grade                                       0.152408
# bathrooms sqft_basement                               0.753630
# bathrooms yr_old                                      0.602279
# sqft_living^2                                         0.304794
# ...                                                        ...
# waterfront condition^2                                0.081124
# waterfront condition grade                            0.085405
# waterfront condition sqft_basement                    0.141298
# waterfront condition yr_old                           0.082643
# waterfront grade^2                                    0.080003
# waterfront grade sqft_basement                        0.133284
# waterfront grade yr_old                               0.093653
# waterfront sqft_basement^2                            0.120566
# waterfront sqft_basement yr_old                       0.156233
# waterfront yr_old^2                                   0.072490
# condition^3                                           0.258618
# condition^2 grade                                     0.320068
# condition^2 sqft_basement                             0.851015
# condition^2 yr_old                                    0.377910
# condition grade^2                                     0.259306
# condition grade sqft_basement                         0.857090
# condition grade yr_old                                0.474208
# condition sqft_basement^2                             0.782195
# condition sqft_basement yr_old                        0.961791
# condition yr_old^2                                    0.355678
# grade^3                                               0.095024
# grade^2 sqft_basement                                 0.766258
# grade^2 yr_old                                        0.519930
# grade sqft_basement^2                                 0.690601
# grade sqft_basement yr_old                                 NaN
# grade yr_old^2                                             NaN
# sqft_basement^3                                            NaN
# sqft_basement^2 yr_old                                     NaN
# sqft_basement yr_old^2                                     NaN
# yr_old^3                                                   NaN
#
#                                     grade yr_old^2  sqft_basement^3  \
# bedrooms                                  0.091710         0.225594
# bathrooms                                 0.355785         0.248059
# sqft_living                               0.191211         0.429857
# sqft_lot                                  0.063814         0.069187
# floors                                    0.293386         0.088380
# waterfront                                0.033168         0.083182
# condition                                 0.311420         0.081231
# grade                                     0.265507         0.207986
# sqft_basement                             0.133083         0.675801
# yr_old                                    0.940807         0.020419
# bedrooms^2                                0.032096         0.157576
# bedrooms bathrooms                        0.241821         0.307993
# bedrooms sqft_living                      0.144661         0.443455
# bedrooms sqft_lot                         0.067342         0.120467
# bedrooms floors                           0.236434         0.053234
# bedrooms waterfront                       0.031131         0.093211
# bedrooms condition                        0.102903         0.228743
# bedrooms grade                            0.172731         0.281874
# bedrooms sqft_basement                    0.111899         0.714062
# bedrooms yr_old                           0.824697         0.113779
# bathrooms^2                               0.300165         0.299920
# bathrooms sqft_living                     0.228608         0.450229
# bathrooms sqft_lot                        0.087509         0.153929
# bathrooms floors                          0.362694         0.084829
# bathrooms waterfront                      0.024521         0.098383
# bathrooms condition                       0.158730         0.282432
# bathrooms grade                           0.334943         0.280746
# bathrooms sqft_basement                   0.072533         0.777184
# bathrooms yr_old                          0.774872         0.183471
# sqft_living^2                             0.148648         0.538317
# ...                                            ...              ...
# waterfront condition^2                    0.041768         0.076477
# waterfront condition grade                0.031325         0.099602
# waterfront condition sqft_basement        0.022941         0.210095
# waterfront condition yr_old               0.067761         0.048525
# waterfront grade^2                        0.017598         0.113451
# waterfront grade sqft_basement            0.013895         0.231921
# waterfront grade yr_old                   0.063624         0.064860
# waterfront sqft_basement^2                0.006577         0.284804
# waterfront sqft_basement yr_old           0.046272         0.143096
# waterfront yr_old^2                       0.079089         0.030209
# condition^3                               0.318060         0.080485
# condition^2 grade                         0.234811         0.167166
# condition^2 sqft_basement                 0.194379         0.601049
# condition^2 yr_old                        0.785430         0.049348
# condition grade^2                         0.045040         0.258702
# condition grade sqft_basement             0.147387         0.720630
# condition grade yr_old                    0.897930         0.089712
# condition sqft_basement^2                 0.103370         0.881396
# condition sqft_basement yr_old            0.413746         0.472598
# condition yr_old^2                        0.948571         0.012253
# grade^3                                   0.236632         0.228892
# grade^2 sqft_basement                     0.083081         0.781259
# grade^2 yr_old                            0.892547         0.135610
# grade sqft_basement^2                     0.054887         0.949206
# grade sqft_basement yr_old                0.399869         0.550687
# grade yr_old^2                                 NaN         0.029213
# sqft_basement^3                                NaN              NaN
# sqft_basement^2 yr_old                         NaN              NaN
# sqft_basement yr_old^2                         NaN              NaN
# yr_old^3                                       NaN              NaN
#
#                                     sqft_basement^2 yr_old  \
# bedrooms                                          0.259469
# bathrooms                                         0.182054
# sqft_living                                       0.370295
# sqft_lot                                          0.009058
# floors                                            0.202250
# waterfront                                        0.074636
# condition                                         0.222988
# grade                                             0.104061
# sqft_basement                                     0.833254
# yr_old                                            0.272263
# bedrooms^2                                        0.179723
# bedrooms bathrooms                                0.254373
# bedrooms sqft_living                              0.375296
# bedrooms sqft_lot                                 0.037196
# bedrooms floors                                   0.023954
# bedrooms waterfront                               0.083886
# bedrooms condition                                0.344784
# bedrooms grade                                    0.246180
# bedrooms sqft_basement                            0.815526
# bedrooms yr_old                                   0.404426
# bathrooms^2                                       0.184295
# bathrooms sqft_living                             0.300743
# bathrooms sqft_lot                                0.038928
# bathrooms floors                                  0.038126
# bathrooms waterfront                              0.084368
# bathrooms condition                               0.309913
# bathrooms grade                                   0.170333
# bathrooms sqft_basement                           0.771074
# bathrooms yr_old                                  0.500223
# sqft_living^2                                     0.359501
# ...                                                    ...
# waterfront condition^2                            0.079060
# waterfront condition grade                        0.086069
# waterfront condition sqft_basement                0.157985
# waterfront condition yr_old                       0.075400
# waterfront grade^2                                0.083684
# waterfront grade sqft_basement                    0.153071
# waterfront grade yr_old                           0.087616
# waterfront sqft_basement^2                        0.155089
# waterfront sqft_basement yr_old                   0.162996
# waterfront yr_old^2                               0.062614
# condition^3                                       0.225888
# condition^2 grade                                 0.284790
# condition^2 sqft_basement                         0.830697
# condition^2 yr_old                                0.297690
# condition grade^2                                 0.241455
# condition grade sqft_basement                     0.845949
# condition grade yr_old                            0.371059
# condition sqft_basement^2                         0.878652
# condition sqft_basement yr_old                    0.898291
# condition yr_old^2                                0.263889
# grade^3                                           0.100445
# grade^2 sqft_basement                             0.766820
# grade^2 yr_old                                    0.404819
# grade sqft_basement^2                             0.791329
# grade sqft_basement yr_old                        0.938735
# grade yr_old^2                                    0.293874
# sqft_basement^3                                   0.704814
# sqft_basement^2 yr_old                                 NaN
# sqft_basement yr_old^2                                 NaN
# yr_old^3                                               NaN
#
#                                     sqft_basement yr_old^2  yr_old^3
# bedrooms                                          0.173690  0.133752
# bathrooms                                         0.062782  0.355065
# sqft_living                                       0.200841  0.229421
# sqft_lot                                          0.037705  0.066839
# floors                                            0.187159  0.223625
# waterfront                                        0.046035  0.018229
# condition                                         0.260477  0.248561
# grade                                             0.015873  0.319048
# sqft_basement                                     0.658554  0.057916
# yr_old                                            0.471455  0.888137
# bedrooms^2                                        0.126570  0.057284
# bedrooms bathrooms                                0.124668  0.258638
# bedrooms sqft_living                              0.205111  0.183711
# bedrooms sqft_lot                                 0.023328  0.073754
# bedrooms floors                                   0.047411  0.207562
# bedrooms waterfront                               0.050498  0.013290
# bedrooms condition                                0.295620  0.031017
# bedrooms grade                                    0.121363  0.224576
# bedrooms sqft_basement                            0.605475  0.040293
# bedrooms yr_old                                   0.563780  0.739659
# bathrooms^2                                       0.052790  0.297017
# bathrooms sqft_living                             0.123349  0.246218
# bathrooms sqft_lot                                0.026504  0.090740
# bathrooms floors                                  0.088183  0.319410
# bathrooms waterfront                              0.047719  0.007724
# bathrooms condition                               0.215036  0.198263
# bathrooms grade                                   0.033512  0.346581
# bathrooms sqft_basement                           0.531953  0.008857
# bathrooms yr_old                                  0.649405  0.668409
# sqft_living^2                                     0.160592  0.178418
# ...                                                    ...       ...
# waterfront condition^2                            0.056859  0.026074
# waterfront condition grade                        0.052627  0.013632
# waterfront condition sqft_basement                0.085810  0.005330
# waterfront condition yr_old                       0.069065  0.052386
# waterfront grade^2                                0.042556  0.000875
# waterfront grade sqft_basement                    0.072360  0.001700
# waterfront grade yr_old                           0.071886  0.043539
# waterfront sqft_basement^2                        0.059827  0.005272
# waterfront sqft_basement yr_old                   0.113517  0.023602
# waterfront yr_old^2                               0.067898  0.067432
# condition^3                                       0.267139  0.259545
# condition^2 grade                                 0.276874  0.144093
# condition^2 sqft_basement                         0.692632  0.112479
# condition^2 yr_old                                0.471194  0.733931
# condition grade^2                                 0.144714  0.133880
# condition grade sqft_basement                     0.644148  0.063450
# condition grade yr_old                            0.549154  0.800665
# condition sqft_basement^2                         0.563678  0.035705
# condition sqft_basement yr_old                    0.928637  0.322020
# condition yr_old^2                                0.502227  0.944004
# grade^3                                           0.022253  0.277031
# grade^2 sqft_basement                             0.523378  0.009272
# grade^2 yr_old                                    0.555096  0.756352
# grade sqft_basement^2                             0.451742  0.003133
# grade sqft_basement yr_old                        0.917660  0.293402
# grade yr_old^2                                    0.531398  0.961979
# sqft_basement^3                                   0.340162  0.012080
# sqft_basement^2 yr_old                            0.826217  0.207424
# sqft_basement yr_old^2                                 NaN  0.458870
# yr_old^3                                               NaN       NaN
#
# [285 rows x 285 columns]

# %%
sns.set(style="white")


# Compute the correlation matrix
corr = X_train.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
X_train.drop(columns=to_drop, inplace=True)
X_test.drop(columns=to_drop, inplace=True)

# %%
len(X_train.columns)
# Out:
# 105

# %% [markdown]
# ***Fit a model on this subset of features***

# %%
lm = linear_model.LinearRegression()
lm.fit(X_train, y_train)
y_train_pred = lm.predict(X_train)
y_pred = lm.predict(X_test)
train_rmse = metrics.mean_absolute_error(y_train, y_train_pred)
test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Training Error: '+ str(train_rmse) )
print('Testing Error: '+ str(test_rmse) )
# Out:
# Training Error: 127541.1854996602
# Testing Error: 190646.38633132546

# %% [markdown]
# ***Compare to the baseline model***

# %%
print('Training Error: '+ str(baseline_train_rmse) )
print('Testing Error: '+ str(baseline_test_rmse) )
# Out:
# Training Error: 123141.87401184587
# Testing Error: 197456.5048648691

# %% [markdown]
# ###  F Test
#
# F Test is a statistical test used to compare between models and check if the difference is significant between the model.
#
# F-Test does a hypothesis testing model X and Y where X is a model created by just a constant and Y is the model created by a constant and a feature.
#
# The least square errors in both the models are compared and checks if the difference in errors between model X and Y are significant or introduced by chance.
#
# F-Test is useful in feature selection as we get to know the significance of each feature in improving the model.
#
# Scikit learn provides the Selecting K best features using F-Test.

# %% [markdown]
# ***Resetting the Data to start off with all variables***

# %%
X_train, X_test, y_train, y_test=  reset_data()

# %% [markdown]
# ***I am using the F-test to sleect the 45 top varaibles for this model***

# %%
from sklearn.feature_selection import SelectKBest, f_regression,mutual_info_regression

selector = SelectKBest(f_regression, k=45)

selector.fit(X_train, y_train)
# Out:
# SelectKBest(k=45, score_func=<function f_regression at 0x1a215681e0>)

# %%
selected_columns = X_train.columns[selector.get_support()]
removed_columns = X_train.columns[~selector.get_support()]
X_train = X_train[selected_columns]
X_test = X_test[selected_columns]

# %%
X_train.shape
# Out:
# (17280, 45)

# %%
lm = linear_model.LinearRegression()
lm.fit(X_train, y_train)
y_train_pred = lm.predict(X_train)
y_pred = lm.predict(X_test)
train_rmse = metrics.mean_absolute_error(y_train, y_train_pred)
test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Training Error: '+ str(train_rmse) )
print('Testing Error: '+ str(test_rmse) )
# Out:
# Training Error: 136795.84084987774
# Testing Error: 200082.43137240116

# %%
print('Training Error: '+ str(baseline_train_rmse) )
print('Testing Error: '+ str(baseline_test_rmse) )
# Out:
# Training Error: 123141.87401184587
# Testing Error: 197456.5048648691

# %% [markdown]
# # Wrapper Methods
#
# Wrapper methods consider the selection of a set of features as a search problem, where different combinations are prepared, evaluated and compared to other combinations. A predictive model is used to evaluate a combination of features and assign a score based on model accuracy.
#
# The search process may be methodical such as a best-first search, it may stochastic such as a random hill-climbing algorithm, or it may use heuristics, like forward and backward passes to add and remove features.
#
# Wrapper Methods promises you a best set of features with a extensive greedy search.
#
# But the main drawbacks of wrapper methods is the sheer amount of models that needs to be trained. It is computationally very expensive and is infeasible with large number of features.

# %% [markdown]
# ![alt text](Wrapper_1.webp)

# %% [markdown]
# ### Recursive Feature Elimination
#
# An example if a wrapper method is the recursive feature elimination algorithm.
#
# As the name suggests, this method eliminates worst performing features on a particular model one after the other until the best subset of features are known.
#
#
# Recursive elimination eliminates the least explaining features one after the other.
# For data with n features,
#
# - On first round ‘n-1’ models are created with combination of all features except one. The least performing feature is removed
#
# - On second round ‘n-2’ models are created by removing another feature.

# %% [markdown]
# <img src='rfe_graph.png' width=500/>

# %%
X_train, X_test, y_train, y_test=  reset_data()

# %%
from sklearn.feature_selection import RFECV

# %%
ols = linear_model.LinearRegression()

# %%
# Create recursive feature eliminator that scores features by mean squared errors
selector = RFECV(estimator=ols, step=1, cv=5, scoring='neg_mean_squared_error')

# Fit recursive feature eliminator 
selector.fit(X_train, y_train)
# Out:
# RFECV(cv=5,
#    estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False),
#    min_features_to_select=1, n_jobs=None, scoring='neg_mean_squared_error',
#    step=1, verbose=0)

# %%
selected_columns = X_train.columns[selector.support_]
removed_columns = X_train.columns[~selector.support_]
X_train = X_train[selected_columns]
X_test = X_test[selected_columns]

# %%
len(selected_columns)
# Out:
# 33

# %%
lm = linear_model.LinearRegression()
lm.fit(X_train, y_train)
y_train_pred = lm.predict(X_train)
y_pred = lm.predict(X_test)
train_rmse = metrics.mean_absolute_error(y_train, y_train_pred)
test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Training Error: '+ str(train_rmse) )
print('Testing Error: '+ str(test_rmse) )
# Out:
# Training Error: 130507.58325137294
# Testing Error: 195108.70248936745

# %%
print('Training Error: '+ str(baseline_train_rmse) )
print('Testing Error: '+ str(baseline_test_rmse) )
# Out:
# Training Error: 123141.87401184587
# Testing Error: 197456.5048648691

# %% [markdown]
# # Embedded Methods
#
# Embedded methods learn which features best contribute to the accuracy of the model while the model is being created. The most common type of embedded feature selection methods are regularization methods.
#
# Regularization methods are also called penalization methods that introduce additional constraints into the optimization of a predictive algorithm (such as a regression algorithm) that bias the model toward lower complexity (fewer coefficients).
#
# Examples of regularization algorithms are the LASSO, Elastic Net and Ridge Regression.

# %% [markdown]
# ![alt text](Embedded_1.webp)

# %%
X_train, X_test, y_train, y_test=  reset_data()

# %%
## training the model
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.1, normalize=False)

lasso.fit(X_train,y_train)

y_train_pred = lasso.predict(X_train)
y_pred = lasso.predict(X_test)

train_rmse = metrics.mean_absolute_error(y_train, y_train_pred)
test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Training Error: '+ str(train_rmse) )
print('Testing Error: '+ str(test_rmse) )
# Out:
# Training Error: 124657.67954850293
# Testing Error: 191140.78330969147
# /Users/swilson5/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
lasso_coef01 = pd.DataFrame(data=lasso.coef_).T
lasso_coef01.columns = X_train.columns
lasso_coef01 = lasso_coef01.T.sort_values(by=0).T
lasso_coef01.plot(kind='bar', title='Modal Coefficients', legend=False, figsize=(16,8))

# %%
len(lasso_coef01.columns)
# Out:
# 285

# %%
lasso_coef01
# Out:
#         yr_old^3         yr_old  sqft_living sqft_basement^2  \
# 0 -280902.149654 -182401.658155               -165599.772298
#
#    bedrooms sqft_living sqft_basement  grade sqft_basement yr_old  \
# 0                      -161281.004227              -139459.010799
#
#    bathrooms^2 waterfront  bedrooms floors grade      bedrooms  sqft_living^3  \
# 0          -127773.728493         -127269.930252 -118783.26398 -114562.864042
#
#    sqft_living floors grade  bedrooms^2 yr_old  sqft_living condition  \
# 0            -114035.387964     -113003.046947         -101937.607434
#
#       sqft_lot^2  bedrooms bathrooms sqft_basement  \
# 0 -101135.436647                     -99828.284226
#
#    condition sqft_basement yr_old  sqft_basement  sqft_living^2 waterfront  \
# 0                    -95279.43501  -94904.372733             -89950.813841
#
#    bedrooms bathrooms sqft_lot  bedrooms waterfront sqft_basement  \
# 0                -89915.222292                      -89378.395767
#
#    bathrooms^2 sqft_basement  bathrooms sqft_living floors  \
# 0              -87361.560446                 -87052.940603
#
#    bedrooms floors waterfront   sqft_living  sqft_living sqft_lot condition  \
# 0               -85952.841362 -85372.465165                   -80600.723194
#
#    floors^2 sqft_basement  sqft_living floors condition  bedrooms^2 floors  \
# 0           -78312.208333                  -73217.03086      -72535.862659
#
#    condition grade  sqft_lot floors waterfront  bedrooms waterfront^2  \
# 0    -71299.014636               -71053.977073           -69253.94917
#
#      sqft_lot^3  bathrooms sqft_lot grade   bathrooms^3  \
# 0 -68878.009175             -68375.766429 -66206.462987
#
#    bedrooms bathrooms condition  grade sqft_basement  bedrooms^2 condition  \
# 0                 -63611.062215        -61685.672683          -59555.91341
#
#    waterfront yr_old  grade yr_old  floors sqft_basement yr_old  \
# 0      -58801.364941 -56985.766442                -56966.768733
#
#    sqft_lot floors  floors yr_old^2  sqft_basement^2 yr_old  \
# 0    -56695.614762     -56684.81647           -56412.055526
#
#    sqft_living waterfront grade  sqft_lot grade yr_old  \
# 0                 -54526.448448          -53355.681274
#
#    floors condition yr_old  floors condition^2  sqft_lot grade sqft_basement  \
# 0            -52996.386444       -52539.050359                 -52473.954789
#
#    bedrooms sqft_living yr_old  waterfront grade yr_old  \
# 0                -51803.722537            -50890.889752
#
#    waterfront grade sqft_basement  bathrooms^2 sqft_lot  sqft_living^2 yr_old  \
# 0                   -49639.875272         -48103.179285          -45825.60534
#
#    bedrooms yr_old^2  bedrooms sqft_living condition  \
# 0       -45098.07264                   -44763.673473
#
#    bedrooms condition sqft_basement      floors^3  floors^2 yr_old  \
# 0                     -44688.246899 -44487.383053    -44220.266498
#
#    sqft_lot floors condition  sqft_living sqft_lot  sqft_living^2 floors  \
# 0              -43475.928622          -43187.79123          -42904.94212
#
#    bedrooms^2 sqft_lot  bathrooms floors grade  sqft_lot floors^2  \
# 0        -41023.015792           -40965.309138      -40262.343897
#
#    waterfront^3  bathrooms floors^2  sqft_living floors yr_old  \
# 0 -39625.815268       -39562.457141              -39257.497017
#
#    condition^2 grade  bathrooms grade yr_old  floors sqft_basement^2  \
# 0      -38037.187116           -37853.302414            -37696.33162
#
#    bedrooms waterfront grade  bathrooms grade sqft_basement     floors^2  \
# 0              -36986.646455                  -36010.540696 -35241.70004
#
#    bedrooms condition yr_old  sqft_lot grade  floors waterfront         grade  \
# 0              -35011.366695   -34586.995083      -34506.503098 -33616.954297
#
#    waterfront condition^2  bathrooms floors  sqft_lot waterfront yr_old  \
# 0           -33335.895962      -32922.05772               -32487.594743
#
#    bathrooms waterfront yr_old  floors grade^2  sqft_lot yr_old  \
# 0                 -32478.20823   -32381.501025    -31642.161035
#
#    waterfront^2 grade  bedrooms sqft_living floors  \
# 0       -30339.751963                -30027.719906
#
#    bedrooms sqft_living sqft_lot  bedrooms grade  floors waterfront condition  \
# 0                  -28713.305149   -28435.720221                -27282.511562
#
#    sqft_living grade^2  sqft_lot floors sqft_basement  \
# 0        -26145.805033                  -25681.558706
#
#    bathrooms sqft_living yr_old  sqft_living waterfront condition  \
# 0                 -25543.608451                     -24561.887471
#
#    sqft_lot condition sqft_basement  bathrooms floors condition  \
# 0                     -24432.946701                -23502.99262
#
#    condition yr_old  waterfront sqft_basement^2  waterfront grade  \
# 0     -22085.158743               -21597.823863     -21316.727923
#
#    bathrooms sqft_lot waterfront  bathrooms waterfront  bedrooms sqft_lot^2  \
# 0                  -21278.770097         -20895.123575         -20506.31133
#
#    sqft_lot^2 floors  bedrooms condition  sqft_lot^2 waterfront  \
# 0      -20487.397956       -20341.265867          -20102.498651
#
#    waterfront condition sqft_basement  bathrooms sqft_basement  \
# 0                       -19743.749985            -19059.912745
#
#    bedrooms grade yr_old  bathrooms^2 yr_old  grade^2 yr_old  \
# 0            -17696.8481       -16175.708508   -15776.215962
#
#    bathrooms condition^2  condition^2 yr_old   condition^2  bedrooms floors  \
# 0          -15507.326456       -15486.906507 -15212.808439    -14961.379646
#
#    sqft_lot yr_old^2        floors  sqft_lot waterfront condition  \
# 0      -14925.233408 -14755.125888                  -14686.496356
#
#    bathrooms^2 sqft_living  sqft_living sqft_basement  \
# 0            -14539.579691              -14217.476401
#
#    condition sqft_basement^2  bedrooms sqft_lot grade  \
# 0              -13929.936241            -13756.901165
#
#    bedrooms floors sqft_basement  sqft_living^2 grade    bedrooms^3  \
# 0                  -13362.028971        -13051.704888 -13021.135554
#
#    bathrooms sqft_lot^2  bathrooms floors waterfront  sqft_lot condition^2  \
# 0         -13012.944241                -12465.859465         -11315.490769
#
#    sqft_living condition^2  waterfront^2 yr_old     bathrooms  \
# 0            -10601.619797        -10368.697635 -10314.436806
#
#    sqft_lot condition grade  waterfront^2  bedrooms waterfront yr_old  \
# 0             -10289.671071 -10166.750687                 -9712.55166
#
#    bathrooms condition  bedrooms sqft_living  sqft_lot floors grade  \
# 0         -9607.995096           -8860.94258           -8814.115208
#
#    waterfront condition yr_old  grade sqft_basement^2  \
# 0                 -8722.279627           -7967.817079
#
#    bathrooms floors yr_old  bathrooms waterfront sqft_basement  \
# 0             -7762.445527                        -7614.406849
#
#    bathrooms sqft_lot yr_old  sqft_basement yr_old^2  bedrooms waterfront  \
# 0               -5509.374533            -4678.048186         -4435.786213
#
#    sqft_living sqft_lot grade  floors waterfront sqft_basement  \
# 0                -3919.691455                     -3528.552338
#
#    bedrooms^2 sqft_living  sqft_lot sqft_basement^2  \
# 0            -3107.164106              -3088.219804
#
#    sqft_lot sqft_basement yr_old  bathrooms condition yr_old  \
# 0                   -2882.638804                 -2822.37412
#
#    bathrooms sqft_living sqft_lot  bedrooms bathrooms^2  \
# 0                     -2255.87183          -1230.214402
#
#    condition sqft_basement  waterfront^2 sqft_basement  bathrooms^2 condition  \
# 0              -600.396855                 -409.001483             996.953335
#
#    bathrooms grade^2  bathrooms waterfront condition  \
# 0        1046.364727                     1931.409464
#
#    bathrooms sqft_living grade  bedrooms bathrooms  waterfront^2 condition  \
# 0                  2706.455173         2740.195674              3049.04927
#
#    sqft_lot^2 condition  sqft_living condition yr_old  waterfront condition  \
# 0           3541.833966                   3869.542552           3985.856138
#
#    sqft_lot waterfront  bedrooms grade^2  sqft_living waterfront yr_old  \
# 0            4494.4628       4704.312248                    5389.399659
#
#    bathrooms sqft_lot sqft_basement  floors grade  bedrooms sqft_lot yr_old  \
# 0                       6670.495486   7158.764273               7383.756742
#
#    bathrooms condition sqft_basement  floors^2 waterfront  bathrooms yr_old^2  \
# 0                        7856.032796          7973.206982         8780.328531
#
#    sqft_lot condition yr_old  bathrooms sqft_lot condition  \
# 0                9370.063097                    9653.93994
#
#    sqft_living sqft_lot yr_old  sqft_lot floors yr_old  \
# 0                 10327.704299             10641.10535
#
#    sqft_living grade sqft_basement  bathrooms sqft_living  \
# 0                     11199.891496           11691.507635
#
#    condition grade yr_old  bedrooms sqft_living waterfront  \
# 0            12210.476298                     12255.537456
#
#    sqft_living floors sqft_basement  sqft_lot grade^2  \
# 0                      13234.115737      13394.945342
#
#    sqft_lot waterfront grade  sqft_living sqft_lot floors  \
# 0               13565.777993                 13667.917826
#
#    condition grade sqft_basement  sqft_living condition sqft_basement  \
# 0                   13931.740902                         14411.785512
#
#    bedrooms^2 bathrooms  floors grade yr_old  sqft_lot^2 sqft_basement  \
# 0          14858.405509         15554.166389              15669.214444
#
#    floors waterfront^2  floors waterfront grade  \
# 0           15671.8511             16236.277198
#
#    sqft_lot waterfront sqft_basement  waterfront grade^2  sqft_living floors  \
# 0                       18517.000385        19535.709858        20146.463321
#
#    bedrooms^2 waterfront  bathrooms yr_old  bedrooms sqft_lot waterfront  \
# 0           20189.565756      21236.584256                  22107.927917
#
#    floors condition  floors^2 grade  bedrooms sqft_lot condition  \
# 0      23063.300075    23108.859125                 23175.438991
#
#    bedrooms bathrooms floors  bedrooms sqft_basement^2  \
# 0               24820.452666              25116.981482
#
#    bedrooms bathrooms sqft_living  bedrooms sqft_basement yr_old  \
# 0                     25941.75131                   26032.831472
#
#    bedrooms bathrooms yr_old  floors grade sqft_basement  bedrooms^2 grade  \
# 0               26034.699079                27713.740064      29347.155138
#
#    waterfront sqft_basement yr_old  sqft_lot sqft_basement  \
# 0                     29550.655258            30131.764441
#
#    bathrooms waterfront grade  sqft_living^2  bedrooms sqft_lot sqft_basement  \
# 0                30481.987054   30680.012852                     31360.092323
#
#    bedrooms grade sqft_basement  condition^2 sqft_basement  \
# 0                  31922.415669               33123.508627
#
#    bedrooms condition^2  sqft_basement^3  bedrooms bathrooms grade  \
# 0          34909.139051     35160.512159              35209.758403
#
#      condition  bathrooms condition grade   bathrooms^2  \
# 0  35525.39075               35915.496177  37909.880641
#
#    bathrooms sqft_basement yr_old  bedrooms sqft_basement  sqft_basement^2  \
# 0                     38671.86901             39922.03773     39933.272367
#
#    condition grade^2       grade^2  sqft_lot waterfront^2  bathrooms^2 floors  \
# 0       40227.139399  40351.398184            41375.65204        41906.374844
#
#    waterfront yr_old^2   condition^3  sqft_living sqft_lot sqft_basement  \
# 0         42097.899082  44903.832164                        45334.748214
#
#    waterfront sqft_basement  floors sqft_basement  bedrooms sqft_lot  \
# 0               45951.37042          46965.795424       47359.029871
#
#    sqft_living sqft_lot waterfront  bedrooms condition grade  \
# 0                     49522.050658              50234.187936
#
#    sqft_living waterfront  sqft_living waterfront^2  bedrooms floors yr_old  \
# 0            51221.819293              53056.657653            53597.355307
#
#    waterfront condition grade  bathrooms waterfront^2  \
# 0                54132.761867            55377.547375
#
#    bedrooms sqft_living grade  sqft_living^2 sqft_basement  \
# 0                57593.506736                 59623.896213
#
#    floors condition grade  floors waterfront yr_old       grade^3  \
# 0            60236.193542              60715.442493  60812.705755
#
#    bathrooms^2 grade  sqft_living^2 sqft_lot  sqft_living sqft_lot^2  \
# 0       62687.078279            63148.423945            63664.046232
#
#    sqft_living yr_old  sqft_living floors waterfront  bathrooms grade  \
# 0        65096.122192                   65764.619857     67740.215929
#
#    bathrooms sqft_lot  sqft_living grade yr_old  sqft_lot condition  \
# 0        68702.814576              75601.486527        76465.783034
#
#    bathrooms sqft_living^2  sqft_living yr_old^2  bathrooms sqft_basement^2  \
# 0             76640.796802          78561.297631               78734.369207
#
#    bedrooms^2 sqft_basement  sqft_living^2 condition  \
# 0               79755.96282             81114.371195
#
#    bedrooms floors condition  bathrooms sqft_living waterfront  \
# 0               81422.258038                      81857.464597
#
#    bathrooms sqft_living sqft_basement  floors^2 condition  floors yr_old  \
# 0                         83060.618427        84491.780494   86511.176162
#
#    bathrooms sqft_living condition  bedrooms sqft_living^2      sqft_lot  \
# 0                     88150.556632            90469.078364  91209.086444
#
#    bedrooms waterfront condition  bathrooms floors sqft_basement  \
# 0                   92140.187006                     92154.34888
#
#    condition yr_old^2  sqft_lot^2 yr_old  bedrooms floors^2  \
# 0        95677.590675       96905.804369      101476.628729
#
#    bathrooms sqft_lot floors  floors condition sqft_basement  \
# 0              103003.137441                   104394.113018
#
#    sqft_living waterfront sqft_basement  grade^2 sqft_basement  \
# 0                         106135.744179          112202.385344
#
#    sqft_living sqft_basement yr_old  sqft_lot^2 grade  \
# 0                     113414.800231     114705.330458
#
#    bedrooms sqft_lot floors  bedrooms bathrooms waterfront     waterfront  \
# 0             114729.196583                   132388.12652  137296.553304
#
#    sqft_basement yr_old  sqft_living grade  sqft_living condition grade  \
# 0         138615.261474      149999.620921                165666.147538
#
#       bedrooms^2  bedrooms yr_old  sqft_living floors^2       yr_old^2  \
# 0  173228.340875    178791.720841          180652.54989  194045.621965
#
#    grade yr_old^2
# 0   247159.617698
